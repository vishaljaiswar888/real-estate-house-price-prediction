# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv("Bengaluru_House_Data.csv")

# %%
data.head()
# Out:
#               area_type   availability                  location       size  \
# 0  Super built-up  Area         19-Dec  Electronic City Phase II      2 BHK
# 1            Plot  Area  Ready To Move          Chikka Tirupathi  4 Bedroom
# 2        Built-up  Area  Ready To Move               Uttarahalli      3 BHK
# 3  Super built-up  Area  Ready To Move        Lingadheeranahalli      3 BHK
# 4  Super built-up  Area  Ready To Move                  Kothanur      2 BHK
#
#    society total_sqft  bath  balcony   price
# 0  Coomee        1056   2.0      1.0   39.07
# 1  Theanmp       2600   5.0      3.0  120.00
# 2      NaN       1440   2.0      3.0   62.00
# 3  Soiewre       1521   3.0      1.0   95.00
# 4      NaN       1200   2.0      1.0   51.00

# %%
data.shape
# Out:
# (13320, 9)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13320 entries, 0 to 13319
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   area_type     13320 non-null  object
#  1   availability  13320 non-null  object
#  2   location      13319 non-null  object
#  3   size          13304 non-null  object
#  4   society       7818 non-null   object
#  5   total_sqft    13320 non-null  object
#  6   bath          13247 non-null  float64
#  7   balcony       12711 non-null  float64
#  8   price         13320 non-null  float64
# dtypes: float64(3), object(6)
# memory usage: 936.7+ KB

# %%
for column in data.columns:
    print(data[column].value_counts())
    print("*"*20)
# Out:
# Super built-up  Area    8790
# Built-up  Area          2418
# Plot  Area              2025
# Carpet  Area              87
# Name: area_type, dtype: int64
# ********************
# Ready To Move    10581
# 18-Dec             307
# 18-May             295
# 18-Apr             271
# 18-Aug             200
#                  ...
# 15-Aug               1
# 17-Jan               1
# 16-Nov               1
# 16-Jan               1
# 14-Jul               1
# Name: availability, Length: 81, dtype: int64
# ********************
# Whitefield                        540
# Sarjapur  Road                    399
# Electronic City                   302
# Kanakpura Road                    273
# Thanisandra                       234
#                                  ...
# Bapuji Layout                       1
# 1st Stage Radha Krishna Layout      1
# BEML Layout 5th stage               1
# singapura paradise                  1
# Abshot Layout                       1
# Name: location, Length: 1305, dtype: int64
# ********************
# 2 BHK         5199
# 3 BHK         4310
# 4 Bedroom      826
# 4 BHK          591
# 3 Bedroom      547
# 1 BHK          538
# 2 Bedroom      329
# 5 Bedroom      297
# 6 Bedroom      191
# 1 Bedroom      105
# 8 Bedroom       84
# 7 Bedroom       83
# 5 BHK           59
# 9 Bedroom       46
# 6 BHK           30
# 7 BHK           17
# 1 RK            13
# 10 Bedroom      12
# 9 BHK            8
# 8 BHK            5
# 11 BHK           2
# 11 Bedroom       2
# 10 BHK           2
# 14 BHK           1
# 13 BHK           1
# 12 Bedroom       1
# 27 BHK           1
# 43 Bedroom       1
# 16 BHK           1
# 19 BHK           1
# 18 Bedroom       1
# Name: size, dtype: int64
# ********************
# GrrvaGr    80
# PrarePa    76
# Sryalan    59
# Prtates    59
# GMown E    56
#            ..
# Amionce     1
# JaghtDe     1
# Jauraht     1
# Brity U     1
# RSntsAp     1
# Name: society, Length: 2688, dtype: int64
# ********************
# 1200    843
# 1100    221
# 1500    205
# 2400    196
# 600     180
#        ...
# 3580      1
# 2461      1
# 1437      1
# 2155      1
# 4689      1
# Name: total_sqft, Length: 2117, dtype: int64
# ********************
# 2.0     6908
# 3.0     3286
# 4.0     1226
# 1.0      788
# 5.0      524
# 6.0      273
# 7.0      102
# 8.0       64
# 9.0       43
# 10.0      13
# 12.0       7
# 13.0       3
# 11.0       3
# 16.0       2
# 27.0       1
# 40.0       1
# 15.0       1
# 14.0       1
# 18.0       1
# Name: bath, dtype: int64
# ********************
# 2.0    5113
# 1.0    4897
# 3.0    1672
# 0.0    1029
# Name: balcony, dtype: int64
# ********************
# 75.00     310
# 65.00     302
# 55.00     275
# 60.00     270
# 45.00     240
#          ...
# 351.00      1
# 54.10       1
# 80.64       1
# 32.73       1
# 488.00      1
# Name: price, Length: 1994, dtype: int64
# ********************

# %%
data.isnull().sum()
# Out:
# area_type          0
# availability       0
# location           1
# size              16
# society         5502
# total_sqft         0
# bath              73
# balcony          609
# price              0
# dtype: int64

# %%
data.drop(columns=["area_type", "availability", "society", "balcony"], inplace=True)

# %%
data.head(3)
# Out:
#                    location       size total_sqft  bath   price
# 0  Electronic City Phase II      2 BHK       1056   2.0   39.07
# 1          Chikka Tirupathi  4 Bedroom       2600   5.0  120.00
# 2               Uttarahalli      3 BHK       1440   2.0   62.00

# %%
data.describe()

# describe gives you numerical columns
# Out:
#                bath         price
# count  13247.000000  13320.000000
# mean       2.692610    112.565627
# std        1.341458    148.971674
# min        1.000000      8.000000
# 25%        2.000000     50.000000
# 50%        2.000000     72.000000
# 75%        3.000000    120.000000
# max       40.000000   3600.000000

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13320 entries, 0 to 13319
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   location    13319 non-null  object
#  1   size        13304 non-null  object
#  2   total_sqft  13320 non-null  object
#  3   bath        13247 non-null  float64
#  4   price       13320 non-null  float64
# dtypes: float64(2), object(3)
# memory usage: 520.4+ KB

# %%
data["location"].value_counts()
# Out:
# Whitefield                        540
# Sarjapur  Road                    399
# Electronic City                   302
# Kanakpura Road                    273
# Thanisandra                       234
#                                  ...
# Bapuji Layout                       1
# 1st Stage Radha Krishna Layout      1
# BEML Layout 5th stage               1
# singapura paradise                  1
# Abshot Layout                       1
# Name: location, Length: 1305, dtype: int64

# %%
data["location"] = data["location"].fillna("Whitefield")

# %%
data["size"].value_counts()
# Out:
# 2 BHK         5199
# 3 BHK         4310
# 4 Bedroom      826
# 4 BHK          591
# 3 Bedroom      547
# 1 BHK          538
# 2 Bedroom      329
# 5 Bedroom      297
# 6 Bedroom      191
# 1 Bedroom      105
# 8 Bedroom       84
# 7 Bedroom       83
# 5 BHK           59
# 9 Bedroom       46
# 6 BHK           30
# 7 BHK           17
# 1 RK            13
# 10 Bedroom      12
# 9 BHK            8
# 8 BHK            5
# 11 BHK           2
# 11 Bedroom       2
# 10 BHK           2
# 14 BHK           1
# 13 BHK           1
# 12 Bedroom       1
# 27 BHK           1
# 43 Bedroom       1
# 16 BHK           1
# 19 BHK           1
# 18 Bedroom       1
# Name: size, dtype: int64

# %%
data["size"] = data["size"].fillna("2 BHK")

# %%
data["bath"].median()
# Out:
# 2.0

# %%
data["bath"] = data["bath"].fillna(data["bath"].median())

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13320 entries, 0 to 13319
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   location    13320 non-null  object
#  1   size        13320 non-null  object
#  2   total_sqft  13320 non-null  object
#  3   bath        13320 non-null  float64
#  4   price       13320 non-null  float64
# dtypes: float64(2), object(3)
# memory usage: 520.4+ KB

# %%
data.head(3)
# Out:
#                    location       size total_sqft  bath   price
# 0  Electronic City Phase II      2 BHK       1056   2.0   39.07
# 1          Chikka Tirupathi  4 Bedroom       2600   5.0  120.00
# 2               Uttarahalli      3 BHK       1440   2.0   62.00

# %%
data["bhk"] = data["size"].str.split().str.get(0).astype(int)

# %%
data.head(3)
# Out:
#                    location       size total_sqft  bath   price  bhk
# 0  Electronic City Phase II      2 BHK       1056   2.0   39.07    2
# 1          Chikka Tirupathi  4 Bedroom       2600   5.0  120.00    4
# 2               Uttarahalli      3 BHK       1440   2.0   62.00    3

# %%
data[data.bhk>20]

# this are actually outliers
# Out:
#                        location        size total_sqft  bath  price  bhk
# 1718  2Electronic City Phase II      27 BHK       8000  27.0  230.0   27
# 4684                Munnekollal  43 Bedroom       2400  40.0  660.0   43

# %%
data["total_sqft"].unique()
# Out:
# array(['1056', '2600', '1440', ..., '1133 - 1384', '774', '4689'],
#       dtype=object)

# %%
# we have to def a function for total_sqft column to fix it

def convertRange(x):
    temp = x.split("-")
    if len(temp)==2:
        return (float(temp[0]) + float(temp[1]))/2
    
    try:
        return float(x)
    except:
        return None

# %%
data["total_sqft"] = data["total_sqft"].apply(convertRange)

# %%
data.total_sqft.unique()
# Out:
# array([1056. , 2600. , 1440. , ..., 1258.5,  774. , 4689. ])

# %%
data.head()
# Out:
#                    location       size  total_sqft  bath   price  bhk
# 0  Electronic City Phase II      2 BHK      1056.0   2.0   39.07    2
# 1          Chikka Tirupathi  4 Bedroom      2600.0   5.0  120.00    4
# 2               Uttarahalli      3 BHK      1440.0   2.0   62.00    3
# 3        Lingadheeranahalli      3 BHK      1521.0   3.0   95.00    3
# 4                  Kothanur      2 BHK      1200.0   2.0   51.00    2

# %% [markdown]
# ### Price Per SqFt

# %%
data["price_per_sqft"] = data["price"]*100000/data["total_sqft"]

# %%
data["price_per_sqft"]
# Out:
# 0         3699.810606
# 1         4615.384615
# 2         4305.555556
# 3         6245.890861
# 4         4250.000000
#              ...
# 13315     6689.834926
# 13316    11111.111111
# 13317     5258.545136
# 13318    10407.336319
# 13319     3090.909091
# Name: price_per_sqft, Length: 13320, dtype: float64

# %%
data.describe()
# Out:
#          total_sqft          bath         price           bhk  price_per_sqft
# count  13274.000000  13320.000000  13320.000000  13320.000000    1.327400e+04
# mean    1559.626694      2.688814    112.565627      2.802778    7.907501e+03
# std     1238.405258      1.338754    148.971674      1.294496    1.064296e+05
# min        1.000000      1.000000      8.000000      1.000000    2.678298e+02
# 25%     1100.000000      2.000000     50.000000      2.000000    4.266865e+03
# 50%     1276.000000      2.000000     72.000000      3.000000    5.434306e+03
# 75%     1680.000000      3.000000    120.000000      3.000000    7.311746e+03
# max    52272.000000     40.000000   3600.000000     43.000000    1.200000e+07

# %%
len(data["location"].unique())
# Out:
# 1305

# %%
data["location"].value_counts()
# Out:
# Whitefield                        541
# Sarjapur  Road                    399
# Electronic City                   302
# Kanakpura Road                    273
# Thanisandra                       234
#                                  ...
# Bapuji Layout                       1
# 1st Stage Radha Krishna Layout      1
# BEML Layout 5th stage               1
# singapura paradise                  1
# Abshot Layout                       1
# Name: location, Length: 1305, dtype: int64

# %%
a = "   radhe ram shyam hanuman  "
a.strip()
# Out:
# 'radhe ram shyam hanuman'

# %%
# strip = starting aur ending ke spaces hatt jayenge

data["location"] = data["location"].apply(lambda x: x.strip())
location_count = data["location"].value_counts()

# %%
location_count
# Out:
# Whitefield                        542
# Sarjapur  Road                    399
# Electronic City                   304
# Kanakpura Road                    273
# Thanisandra                       237
#                                  ...
# Bapuji Layout                       1
# 1st Stage Radha Krishna Layout      1
# BEML Layout 5th stage               1
# singapura paradise                  1
# Abshot Layout                       1
# Name: location, Length: 1294, dtype: int64

# %%
location_count_less_10 = location_count[location_count<=10]
location_count_less_10
# Out:
# Dairy Circle                      10
# Nagappa Reddy Layout              10
# Basapura                          10
# 1st Block Koramangala             10
# Sector 1 HSR Layout               10
#                                   ..
# Bapuji Layout                      1
# 1st Stage Radha Krishna Layout     1
# BEML Layout 5th stage              1
# singapura paradise                 1
# Abshot Layout                      1
# Name: location, Length: 1053, dtype: int64

# %%
data["location"] = data["location"].apply(lambda x: "others" if x in location_count_less_10 else x)

# %%
len(data.location.unique())

# see location counts are now reduced from 1305 to 242
# Out:
# 242

# %%
data.location.value_counts()
# Out:
# others                2885
# Whitefield             542
# Sarjapur  Road         399
# Electronic City        304
# Kanakpura Road         273
#                       ...
# Nehru Nagar             11
# Banjara Layout          11
# LB Shastri Nagar        11
# Pattandur Agrahara      11
# Narayanapura            11
# Name: location, Length: 242, dtype: int64

# %% [markdown]
# ### Outlier Detection & Removal

# %%
data.describe()
# Out:
#          total_sqft          bath         price           bhk  price_per_sqft
# count  13274.000000  13320.000000  13320.000000  13320.000000    1.327400e+04
# mean    1559.626694      2.688814    112.565627      2.802778    7.907501e+03
# std     1238.405258      1.338754    148.971674      1.294496    1.064296e+05
# min        1.000000      1.000000      8.000000      1.000000    2.678298e+02
# 25%     1100.000000      2.000000     50.000000      2.000000    4.266865e+03
# 50%     1276.000000      2.000000     72.000000      3.000000    5.434306e+03
# 75%     1680.000000      3.000000    120.000000      3.000000    7.311746e+03
# max    52272.000000     40.000000   3600.000000     43.000000    1.200000e+07

# %%
(data["total_sqft"]/data["bhk"]).describe()
# Out:
# count    13274.000000
# mean       575.074878
# std        388.205175
# min          0.250000
# 25%        473.333333
# 50%        552.500000
# 75%        625.000000
# max      26136.000000
# dtype: float64

# %%
data = data[((data["total_sqft"]/data["bhk"])>=300)]
data.describe()
# Out:
#          total_sqft          bath         price           bhk  price_per_sqft
# count  12530.000000  12530.000000  12530.000000  12530.000000    12530.000000
# mean    1594.564544      2.559537    111.382401      2.650838     6303.979357
# std     1261.271296      1.077938    152.077329      0.976678     4162.237981
# min      300.000000      1.000000      8.440000      1.000000      267.829813
# 25%     1116.000000      2.000000     49.000000      2.000000     4210.526316
# 50%     1300.000000      2.000000     70.000000      3.000000     5294.117647
# 75%     1700.000000      3.000000    115.000000      3.000000     6916.666667
# max    52272.000000     16.000000   3600.000000     16.000000   176470.588235

# %%
data.shape
# Out:
# (12530, 7)

# %%
data.price_per_sqft.describe()
# Out:
# count     12530.000000
# mean       6303.979357
# std        4162.237981
# min         267.829813
# 25%        4210.526316
# 50%        5294.117647
# 75%        6916.666667
# max      176470.588235
# Name: price_per_sqft, dtype: float64

# %%
# to remove outliers from price_per_sqft column

def remove_outliers_sqft(df):
    df_output = pd.DataFrame()
    for key, subdf in df.groupby("location"):
        m = np.mean(subdf.price_per_sqft)
        
        st = np.std(subdf.price_per_sqft)
        
        gen_df = subdf[(subdf.price_per_sqft>(m-st)) & (subdf.price_per_sqft<=(m+st))]
        df_output = pd.concat([df_output, gen_df], ignore_index=True)
    return df_output

# %%
data = remove_outliers_sqft(data)
data.describe()
# Out:
#          total_sqft          bath         price           bhk  price_per_sqft
# count  10301.000000  10301.000000  10301.000000  10301.000000    10301.000000
# mean    1508.440608      2.471702     91.286372      2.574896     5659.062876
# std      880.694214      0.979449     86.342786      0.897649     2265.774749
# min      300.000000      1.000000     10.000000      1.000000     1250.000000
# 25%     1110.000000      2.000000     49.000000      2.000000     4244.897959
# 50%     1286.000000      2.000000     67.000000      2.000000     5175.600739
# 75%     1650.000000      3.000000    100.000000      3.000000     6428.571429
# max    30400.000000     16.000000   2200.000000     16.000000    24509.803922

# %%
### Now to remove outliers from bhk column

for location, location_df in data.groupby("location"):
    print(location_df)
# Out:
#               location   size  total_sqft  bath  price  bhk  price_per_sqft
# 0  1st Block Jayanagar  4 BHK      2850.0   4.0  428.0    4    15017.543860
# 1  1st Block Jayanagar  3 BHK      1630.0   3.0  194.0    3    11901.840491
# 2  1st Block Jayanagar  3 BHK      1875.0   2.0  235.0    3    12533.333333
# 3  1st Block Jayanagar  3 BHK      1200.0   2.0  130.0    3    10833.333333
# 4  1st Block Jayanagar  2 BHK      1235.0   2.0  148.0    2    11983.805668
# 5  1st Block Jayanagar  4 BHK      2750.0   4.0  413.0    4    15018.181818
# 6  1st Block Jayanagar  4 BHK      2450.0   4.0  368.0    4    15020.408163
#               location       size  total_sqft  bath  price  bhk  \
# 7   1st Phase JP Nagar      4 BHK      2825.0   4.0  250.0    4
# 8   1st Phase JP Nagar      3 BHK      1875.0   3.0  167.0    3
# 9   1st Phase JP Nagar  5 Bedroom      1500.0   5.0   85.0    5
# 10  1st Phase JP Nagar      3 BHK      2065.0   4.0  210.0    3
# 11  1st Phase JP Nagar      3 BHK      2024.0   3.0  157.0    3
# 12  1st Phase JP Nagar      3 BHK      2059.0   3.0  225.0    3
# 13  1st Phase JP Nagar      2 BHK      1394.0   2.0  100.0    2
# 14  1st Phase JP Nagar      2 BHK      1077.0   2.0   93.0    2
# 15  1st Phase JP Nagar  2 Bedroom      1566.0   2.0  180.0    2
# 16  1st Phase JP Nagar      1 BHK       840.0   2.0   50.0    1
# 17  1st Phase JP Nagar      3 BHK      1590.0   3.0  131.0    3
# 18  1st Phase JP Nagar      3 BHK      2180.0   3.0  210.0    3
# 19  1st Phase JP Nagar      2 BHK      1180.0   2.0   88.5    2
# 20  1st Phase JP Nagar      2 BHK      1200.0   2.0   86.0    2
# 21  1st Phase JP Nagar      2 BHK      1394.0   2.0   85.0    2
# 22  1st Phase JP Nagar      3 BHK      2077.0   3.0  175.0    3
# 23  1st Phase JP Nagar      4 BHK      4550.0   2.0  240.0    4
# 24  1st Phase JP Nagar      2 BHK      1205.0   2.0   85.0    2
# 25  1st Phase JP Nagar      4 BHK      2615.0   5.0  222.0    4
# 26  1st Phase JP Nagar      2 BHK       900.0   2.0   75.0    2
#
#     price_per_sqft
# 7      8849.557522
# 8      8906.666667
# 9      5666.666667
# 10    10169.491525
# 11     7756.916996
# 12    10927.634774
# 13     7173.601148
# 14     8635.097493
# 15    11494.252874
# 16     5952.380952
# 17     8238.993711
# 18     9633.027523
# 19     7500.000000
# 20     7166.666667
# 21     6097.560976
# 22     8425.613866
# 23     5274.725275
# 24     7053.941909
# 25     8489.483748
# 26     8333.333333
#                      location   size  total_sqft  bath  price  bhk  \
# 27  2nd Phase Judicial Layout  3 BHK      1450.0   2.0  50.75    3
# 28  2nd Phase Judicial Layout  2 BHK      1150.0   2.0  40.25    2
# 29  2nd Phase Judicial Layout  3 BHK      1350.0   2.0  47.25    3
# 30  2nd Phase Judicial Layout  3 BHK      1350.0   2.0  47.25    3
# 31  2nd Phase Judicial Layout  2 BHK       900.0   2.0  41.00    2
# 32  2nd Phase Judicial Layout  3 BHK      1681.0   3.0  69.00    3
# 33  2nd Phase Judicial Layout  3 BHK      1350.0   2.0  47.25    3
# 34  2nd Phase Judicial Layout  2 BHK      1150.0   2.0  40.25    2
#
#     price_per_sqft
# 27     3500.000000
# 28     3500.000000
# 29     3500.000000
# 30     3500.000000
# 31     4555.555556
# 32     4104.699584
# 33     3500.000000
# 34     3500.000000
#                 location       size  total_sqft  bath  price  bhk  \
# 35  2nd Stage Nagarbhavi  4 Bedroom      1500.0   4.0  220.0    4
# 36  2nd Stage Nagarbhavi  6 Bedroom      3000.0   8.0  451.0    6
# 37  2nd Stage Nagarbhavi  6 Bedroom      2400.0   8.0  450.0    6
# 38  2nd Stage Nagarbhavi  4 Bedroom      1350.0   4.0  200.0    4
# 39  2nd Stage Nagarbhavi  4 Bedroom      1200.0   4.0  225.0    4
# 40  2nd Stage Nagarbhavi  4 Bedroom      1500.0   3.0  230.0    4
#
#     price_per_sqft
# 35    14666.666667
# 36    15033.333333
# 37    18750.000000
# 38    14814.814815
# 39    18750.000000
# 40    15333.333333
#                 location       size  total_sqft  bath  price  bhk  \
# 41  5th Block Hbr Layout      2 BHK      1206.0   2.0   56.0    2
# 42  5th Block Hbr Layout      3 BHK      1270.0   2.0   70.0    3
# 43  5th Block Hbr Layout      2 BHK      1312.0   2.0   69.0    2
# 44  5th Block Hbr Layout      2 BHK      1100.0   2.0   48.0    2
# 45  5th Block Hbr Layout  5 Bedroom      3600.0   5.0  130.0    5
# 46  5th Block Hbr Layout      6 BHK      5100.0   5.0  300.0    6
#
#     price_per_sqft
# 41     4643.449420
# 42     5511.811024
# 43     5259.146341
# 44     4363.636364
# 45     3611.111111
# 46     5882.352941
#               location   size  total_sqft  bath  price  bhk  price_per_sqft
# 47  5th Phase JP Nagar  2 BHK      1075.0   2.0   60.0    2     5581.395349
# 48  5th Phase JP Nagar  2 BHK      1150.0   3.0   52.5    2     4565.217391
# 49  5th Phase JP Nagar  2 BHK      1256.0   2.0   62.8    2     5000.000000
# 50  5th Phase JP Nagar  2 BHK      1207.0   2.0   63.0    2     5219.552610
# 51  5th Phase JP Nagar  3 BHK      1725.0   2.0  100.0    3     5797.101449
# 52  5th Phase JP Nagar  2 BHK      1440.0   2.0   60.0    2     4166.666667
# 53  5th Phase JP Nagar  3 BHK      1700.0   2.0  100.0    3     5882.352941
# 54  5th Phase JP Nagar  3 BHK      1485.0   2.0   67.0    3     4511.784512
# 55  5th Phase JP Nagar  5 BHK      2500.0   5.0  110.0    5     4400.000000
# 56  5th Phase JP Nagar  1 BHK       600.0   1.0   30.0    1     5000.000000
# 57  5th Phase JP Nagar  2 BHK      1390.0   2.0   65.0    2     4676.258993
# 58  5th Phase JP Nagar  2 BHK      1256.0   2.0   62.8    2     5000.000000
# 59  5th Phase JP Nagar  2 BHK      1000.0   2.0   48.0    2     4800.000000
# 60  5th Phase JP Nagar  3 BHK      1350.0   2.0   75.0    3     5555.555556
# 61  5th Phase JP Nagar  1 BHK       552.0   1.0   23.5    1     4257.246377
# 62  5th Phase JP Nagar  2 BHK      1200.0   2.0   51.0    2     4250.000000
# 63  5th Phase JP Nagar  3 BHK      1240.0   3.0   60.0    3     4838.709677
# 64  5th Phase JP Nagar  3 BHK      1550.0   3.0   75.0    3     4838.709677
# 65  5th Phase JP Nagar  3 BHK      1485.0   2.0   66.0    3     4444.444444
# 66  5th Phase JP Nagar  2 BHK      1030.0   2.0   57.0    2     5533.980583
# 67  5th Phase JP Nagar  2 BHK      1200.0   2.0   68.0    2     5666.666667
# 68  5th Phase JP Nagar  2 BHK      1190.0   2.0   61.8    2     5193.277311
# 69  5th Phase JP Nagar  5 BHK      4000.0   5.0  170.0    5     4250.000000
# 70  5th Phase JP Nagar  2 BHK      1080.0   2.0   53.0    2     4907.407407
# 71  5th Phase JP Nagar  2 BHK      1041.0   2.0   54.0    2     5187.319885
# 72  5th Phase JP Nagar  2 BHK       812.0   2.0   42.0    2     5172.413793
# 73  5th Phase JP Nagar  2 BHK      1010.0   2.0   57.0    2     5643.564356
# 74  5th Phase JP Nagar  3 BHK      1450.0   2.0   73.0    3     5034.482759
# 75  5th Phase JP Nagar  2 BHK      1075.0   2.0   60.0    2     5581.395349
#               location   size  total_sqft  bath  price  bhk  price_per_sqft
# 76  6th Phase JP Nagar  2 BHK      1192.0   2.0   74.0    2     6208.053691
# 77  6th Phase JP Nagar  2 BHK      1180.0   2.0   80.0    2     6779.661017
# 78  6th Phase JP Nagar  4 BHK      3245.0   4.0  250.0    4     7704.160247
# 79  6th Phase JP Nagar  3 BHK      1645.0   3.0  100.0    3     6079.027356
# 80  6th Phase JP Nagar  2 BHK      1140.0   2.0   65.0    2     5701.754386
# 81  6th Phase JP Nagar  3 BHK      2040.0   3.0  200.0    3     9803.921569
# 82  6th Phase JP Nagar  2 BHK      1213.0   2.0   63.0    2     5193.734542
# 83  6th Phase JP Nagar  2 BHK      1216.0   2.0   60.0    2     4934.210526
# 84  6th Phase JP Nagar  2 BHK      1460.0   2.0   80.0    2     5479.452055
# 85  6th Phase JP Nagar  3 BHK      2003.0   3.0  200.0    3     9985.022466
# 86  6th Phase JP Nagar  3 BHK      1810.0   3.0  131.0    3     7237.569061
# 87  6th Phase JP Nagar  3 BHK      1515.0   2.0  135.0    3     8910.891089
# 88  6th Phase JP Nagar  2 BHK      1192.0   2.0   75.0    2     6291.946309
# 89  6th Phase JP Nagar  2 BHK      1280.0   2.0   88.0    2     6875.000000
#                location   size  total_sqft  bath  price  bhk  price_per_sqft
# 90   7th Phase JP Nagar  2 BHK      1080.0   2.0   72.0    2     6666.666667
# 91   7th Phase JP Nagar  2 BHK      1270.0   2.0   93.0    2     7322.834646
# 92   7th Phase JP Nagar  3 BHK      1420.0   2.0  100.0    3     7042.253521
# 93   7th Phase JP Nagar  3 BHK      1850.0   3.0  150.0    3     8108.108108
# 94   7th Phase JP Nagar  2 BHK      1245.0   2.0   94.0    2     7550.200803
# ..                  ...    ...         ...   ...    ...  ...             ...
# 186  7th Phase JP Nagar  3 BHK      1430.0   2.0  102.0    3     7132.867133
# 187  7th Phase JP Nagar  2 BHK      1128.0   2.0   60.0    2     5319.148936
# 188  7th Phase JP Nagar  2 BHK      1140.0   2.0   57.0    2     5000.000000
# 189  7th Phase JP Nagar  3 BHK      1420.0   3.0   90.0    3     6338.028169
# 190  7th Phase JP Nagar  2 BHK      1530.0   2.0  108.0    2     7058.823529
#
# [101 rows x 7 columns]
#                location       size  total_sqft  bath    price  bhk  \
# 191  8th Phase JP Nagar      2 BHK      1073.5   2.0   54.005    2
# 192  8th Phase JP Nagar      1 BHK       451.0   1.0   29.900    1
# 193  8th Phase JP Nagar      3 BHK      1240.0   3.0   43.500    3
# 194  8th Phase JP Nagar      2 BHK      1062.0   2.0   42.470    2
# 195  8th Phase JP Nagar      3 BHK      1230.0   2.0   43.500    3
# 196  8th Phase JP Nagar      3 BHK      1455.0   3.0   73.310    3
# 197  8th Phase JP Nagar      2 BHK       871.0   2.0   55.000    2
# 198  8th Phase JP Nagar      2 BHK      1098.0   2.0   43.910    2
# 199  8th Phase JP Nagar      3 BHK      1800.0   3.0   80.000    3
# 200  8th Phase JP Nagar  4 Bedroom      2700.0   4.0  130.000    4
# 201  8th Phase JP Nagar      2 BHK      1080.0   2.0   38.000    2
# 202  8th Phase JP Nagar      2 BHK      1059.0   2.0   34.500    2
# 203  8th Phase JP Nagar      2 BHK      1080.0   2.0   35.000    2
# 204  8th Phase JP Nagar      3 BHK      1275.0   2.0   41.500    3
# 205  8th Phase JP Nagar      2 BHK      1062.0   2.0   42.470    2
# 206  8th Phase JP Nagar      1 BHK       500.0   1.0   31.000    1
# 207  8th Phase JP Nagar      2 BHK      1100.0   2.0   35.000    2
# 208  8th Phase JP Nagar      4 BHK      2100.0   4.0   92.000    4
# 209  8th Phase JP Nagar      2 BHK      1035.0   2.0   39.330    2
# 210  8th Phase JP Nagar      2 BHK       909.0   2.0   40.900    2
# 211  8th Phase JP Nagar      3 BHK      1431.5   3.0   72.020    3
# 212  8th Phase JP Nagar  3 Bedroom      1900.0   4.0   90.000    3
# 213  8th Phase JP Nagar      1 BHK       500.0   1.0   30.000    1
# 214  8th Phase JP Nagar      2 BHK      1125.0   2.0   36.940    2
# 215  8th Phase JP Nagar      2 BHK      1100.0   2.0   35.000    2
# 216  8th Phase JP Nagar      2 BHK      1089.0   2.0   43.550    2
# 217  8th Phase JP Nagar      3 BHK      1605.0   2.0   65.000    3
# 218  8th Phase JP Nagar      3 BHK      1504.0   2.0   83.000    3
# 219  8th Phase JP Nagar  4 Bedroom      2600.0   4.0  115.000    4
# 220  8th Phase JP Nagar      3 BHK      1368.0   2.0   54.710    3
# 221  8th Phase JP Nagar      2 BHK      1089.0   2.0   43.550    2
# 222  8th Phase JP Nagar      3 BHK      1224.0   2.0   48.950    3
# 223  8th Phase JP Nagar      2 BHK      1513.0   2.0   62.000    2
# 224  8th Phase JP Nagar      2 BHK      1298.0   2.0   59.000    2
# 225  8th Phase JP Nagar      2 BHK      1006.0   2.0   44.000    2
# 226  8th Phase JP Nagar      1 BHK       500.0   1.0   33.000    1
# 227  8th Phase JP Nagar      2 BHK      1160.0   2.0   95.000    2
# 228  8th Phase JP Nagar      2 BHK      1245.0   2.0   59.000    2
# 229  8th Phase JP Nagar      2 BHK      1510.0   2.0   80.000    2
# 230  8th Phase JP Nagar      3 BHK      3300.0   3.0  165.000    3
# 231  8th Phase JP Nagar  5 Bedroom      1730.0   5.0   75.000    5
# 232  8th Phase JP Nagar      3 BHK      1296.0   2.0   51.830    3
# 233  8th Phase JP Nagar      3 BHK      1275.0   3.0   45.000    3
# 234  8th Phase JP Nagar      2 BHK      1046.0   2.0   48.000    2
# 235  8th Phase JP Nagar      3 BHK      1269.0   2.0   50.750    3
# 236  8th Phase JP Nagar      3 BHK      1408.0   3.0   80.000    3
# 237  8th Phase JP Nagar      3 BHK      1500.0   2.0   55.000    3
#
#      price_per_sqft
# 191     5030.740568
# 192     6629.711752
# 193     3508.064516
# 194     3999.058380
# 195     3536.585366
# 196     5038.487973
# 197     6314.580941
# 198     3999.089253
# 199     4444.444444
# 200     4814.814815
# 201     3518.518519
# 202     3257.790368
# 203     3240.740741
# 204     3254.901961
# 205     3999.058380
# 206     6200.000000
# 207     3181.818182
# 208     4380.952381
# 209     3800.000000
# 210     4499.449945
# 211     5031.086273
# 212     4736.842105
# 213     6000.000000
# 214     3283.555556
# 215     3181.818182
# 216     3999.081726
# 217     4049.844237
# 218     5518.617021
# 219     4423.076923
# 220     3999.269006
# 221     3999.081726
# 222     3999.183007
# 223     4097.818903
# 224     4545.454545
# 225     4373.757455
# 226     6600.000000
# 227     8189.655172
# 228     4738.955823
# 229     5298.013245
# 230     5000.000000
# 231     4335.260116
# 232     3999.228395
# 233     3529.411765
# 234     4588.910134
# 235     3999.211978
# 236     5681.818182
# 237     3666.666667
#                location       size  total_sqft  bath   price  bhk  \
# 238  9th Phase JP Nagar      2 BHK     1005.00   2.0   50.00    2
# 239  9th Phase JP Nagar      3 BHK     1890.00   2.0   85.00    3
# 240  9th Phase JP Nagar      2 BHK     1100.00   2.0   65.00    2
# 241  9th Phase JP Nagar      2 BHK     1080.00   2.0   37.00    2
# 242  9th Phase JP Nagar      2 BHK     1035.00   2.0   45.00    2
# 243  9th Phase JP Nagar      4 BHK     5000.00   4.0  290.00    4
# 244  9th Phase JP Nagar      2 BHK     1164.00   2.0   56.00    2
# 245  9th Phase JP Nagar      2 BHK     1005.00   2.0   42.00    2
# 246  9th Phase JP Nagar      2 BHK     1127.00   2.0   50.00    2
# 247  9th Phase JP Nagar      2 BHK     1005.00   2.0   43.00    2
# 248  9th Phase JP Nagar      2 BHK      835.00   2.0   37.00    2
# 249  9th Phase JP Nagar      2 BHK     1050.00   2.0   39.00    2
# 250  9th Phase JP Nagar      2 BHK      660.00   2.0   27.00    2
# 251  9th Phase JP Nagar      1 BHK      600.00   1.0   20.00    1
# 252  9th Phase JP Nagar      2 BHK     1466.00   2.0   71.00    2
# 253  9th Phase JP Nagar      3 BHK     1890.00   2.0   93.00    3
# 254  9th Phase JP Nagar      2 BHK     1079.00   2.0   60.00    2
# 255  9th Phase JP Nagar      2 BHK     1480.00   2.0   80.00    2
# 256  9th Phase JP Nagar  2 Bedroom     1200.00   2.0   80.00    2
# 257  9th Phase JP Nagar      2 BHK      905.00   2.0   32.00    2
# 258  9th Phase JP Nagar      2 BHK     1073.00   2.0   52.36    2
# 259  9th Phase JP Nagar      3 BHK     1719.30   2.0   88.00    3
# 260  9th Phase JP Nagar      3 BHK     1780.00   3.0   88.00    3
# 261  9th Phase JP Nagar      3 BHK     1300.00   2.0   58.00    3
# 262  9th Phase JP Nagar      3 BHK     1522.00   3.0   90.00    3
# 263  9th Phase JP Nagar      3 BHK     1571.00   3.0   65.00    3
# 264  9th Phase JP Nagar  4 Bedroom     1900.00   4.0   80.00    4
# 265  9th Phase JP Nagar      2 BHK      890.00   2.0   45.00    2
# 266  9th Phase JP Nagar      3 BHK     1240.00   2.0   39.89    3
# 267  9th Phase JP Nagar      4 BHK     5000.00   4.0  300.00    4
# 268  9th Phase JP Nagar      3 BHK     1240.00   2.0   42.85    3
# 269  9th Phase JP Nagar      2 BHK     1050.00   2.0   35.00    2
# 270  9th Phase JP Nagar      2 BHK     1331.95   2.0   69.00    2
#
#      price_per_sqft
# 238     4975.124378
# 239     4497.354497
# 240     5909.090909
# 241     3425.925926
# 242     4347.826087
# 243     5800.000000
# 244     4810.996564
# 245     4179.104478
# 246     4436.557232
# 247     4278.606965
# 248     4431.137725
# 249     3714.285714
# 250     4090.909091
# 251     3333.333333
# 252     4843.110505
# 253     4920.634921
# 254     5560.704356
# 255     5405.405405
# 256     6666.666667
# 257     3535.911602
# 258     4879.776328
# 259     5118.362124
# 260     4943.820225
# 261     4461.538462
# 262     5913.272011
# 263     4137.492043
# 264     4210.526316
# 265     5056.179775
# 266     3216.935484
# 267     6000.000000
# 268     3455.645161
# 269     3333.333333
# 270     5180.374639
#         location   size  total_sqft  bath  price  bhk  price_per_sqft
# 271  AECS Layout  2 BHK      1100.0   2.0   45.0    2     4090.909091
# 272  AECS Layout  2 BHK      1028.0   2.0   42.0    2     4085.603113
# 273  AECS Layout  2 BHK      1199.0   2.0   65.0    2     5421.184320
# 274  AECS Layout  2 BHK      1080.0   2.0   55.0    2     5092.592593
# 275  AECS Layout  2 BHK      1123.0   2.0   64.0    2     5699.020481
# 276  AECS Layout  2 BHK      1308.0   2.0   60.0    2     4587.155963
# 277  AECS Layout  2 BHK      1005.0   2.0   55.0    2     5472.636816
# 278  AECS Layout  3 BHK      2000.0   3.0   90.0    3     4500.000000
#      location       size  total_sqft  bath   price  bhk  price_per_sqft
# 279  Abbigere      2 BHK       985.0   2.0   40.39    2     4100.507614
# 280  Abbigere  6 Bedroom      2200.0   6.0   68.00    6     3090.909091
# 281  Abbigere      1 BHK       765.0   2.0   30.00    1     3921.568627
# 282  Abbigere      2 BHK       880.0   2.0   35.00    2     3977.272727
# 283  Abbigere      2 BHK       795.0   2.0   32.54    2     4093.081761
# 284  Abbigere      2 BHK      1005.0   2.0   39.59    2     3939.303483
# 285  Abbigere      1 BHK       734.0   1.0   19.82    1     2700.272480
# 286  Abbigere      3 BHK      1260.0   2.0   45.00    3     3571.428571
# 287  Abbigere      2 BHK      1020.0   2.0   41.82    2     4100.000000
# 288  Abbigere      2 BHK       985.0   2.0   40.39    2     4100.507614
# 289  Abbigere  6 Bedroom      2500.0   6.0   81.00    6     3240.000000
# 290  Abbigere      2 BHK       795.0   2.0   32.54    2     4093.081761
# 291  Abbigere      2 BHK      1130.0   2.0   46.33    2     4100.000000
# 292  Abbigere      2 BHK       795.0   1.0   32.60    2     4100.628931
# 293  Abbigere  8 Bedroom      3000.0   8.0  150.00    8     5000.000000
# 294  Abbigere      2 BHK       985.0   2.0   38.92    2     3951.269036
# 295  Abbigere      2 BHK      1000.0   2.0   41.00    2     4100.000000
# 296  Abbigere      2 BHK       995.0   2.0   40.80    2     4100.502513
# 297  Abbigere      2 BHK      1020.0   2.0   40.80    2     4000.000000
#           location       size  total_sqft  bath  price  bhk  price_per_sqft
# 298  Akshaya Nagar      2 BHK      1388.0   2.0   57.0    2     4106.628242
# 299  Akshaya Nagar      2 BHK      1070.0   2.0   54.0    2     5046.728972
# 300  Akshaya Nagar      2 BHK      1280.0   2.0   58.0    2     4531.250000
# 301  Akshaya Nagar      3 BHK      1662.0   3.0   85.1    3     5120.336943
# 302  Akshaya Nagar      3 BHK      1897.0   3.0  120.0    3     6325.777543
# 303  Akshaya Nagar      3 BHK      1410.0   2.0   75.0    3     5319.148936
# 304  Akshaya Nagar      3 BHK      1360.0   2.0   85.0    3     6250.000000
# 305  Akshaya Nagar      3 BHK      1600.0   2.0   65.0    3     4062.500000
# 306  Akshaya Nagar      3 BHK      1410.0   2.0   80.0    3     5673.758865
# 307  Akshaya Nagar      3 BHK      1662.0   3.0   85.0    3     5114.320096
# 308  Akshaya Nagar      3 BHK      1662.0   3.0   85.5    3     5144.404332
# 309  Akshaya Nagar      2 BHK      1280.0   2.0   60.0    2     4687.500000
# 310  Akshaya Nagar      3 BHK      1666.0   3.0   95.0    3     5702.280912
# 311  Akshaya Nagar      3 BHK      1575.0   3.0   90.0    3     5714.285714
# 312  Akshaya Nagar      3 BHK      1430.0   2.0   75.0    3     5244.755245
# 313  Akshaya Nagar      3 BHK      1419.0   2.0   73.0    3     5144.467935
# 314  Akshaya Nagar      2 BHK      1280.0   2.0   60.0    2     4687.500000
# 315  Akshaya Nagar      2 BHK      1200.0   2.0   50.0    2     4166.666667
# 316  Akshaya Nagar      2 BHK      1092.0   2.0   60.0    2     5494.505495
# 317  Akshaya Nagar      3 BHK      1690.0   3.0   85.0    3     5029.585799
# 318  Akshaya Nagar      3 BHK      1700.0   3.0   80.0    3     4705.882353
# 319  Akshaya Nagar      3 BHK      1897.0   4.0   93.0    3     4902.477596
# 320  Akshaya Nagar      3 BHK      1884.0   3.0   98.0    3     5201.698514
# 321  Akshaya Nagar      2 BHK      1314.0   2.0   68.8    2     5235.920852
# 322  Akshaya Nagar      3 BHK      1690.0   3.0   85.0    3     5029.585799
# 323  Akshaya Nagar      2 BHK      1265.0   2.0   67.0    2     5296.442688
# 324  Akshaya Nagar      2 BHK      1126.0   2.0   55.0    2     4884.547069
# 325  Akshaya Nagar      3 BHK      2300.0   4.0  102.0    3     4434.782609
# 326  Akshaya Nagar      3 BHK      1662.0   3.0   90.0    3     5415.162455
# 327  Akshaya Nagar      3 BHK      1420.0   2.0   75.0    3     5281.690141
# 328  Akshaya Nagar      3 BHK      1412.0   2.0   88.0    3     6232.294618
# 329  Akshaya Nagar      3 BHK      1434.0   3.0   84.0    3     5857.740586
# 330  Akshaya Nagar      3 BHK      1890.0   4.0  100.0    3     5291.005291
# 331  Akshaya Nagar  3 Bedroom      2650.0   3.0  125.0    3     4716.981132
# 332  Akshaya Nagar      3 BHK      1419.0   2.0   87.0    3     6131.078224
# 333  Akshaya Nagar      2 BHK      1300.0   2.0   54.0    2     4153.846154
# 334  Akshaya Nagar      3 BHK      1690.0   3.0   85.0    3     5029.585799
# 335  Akshaya Nagar      2 BHK      1113.0   2.0   52.0    2     4672.057502
# 336  Akshaya Nagar      3 BHK      1820.0   4.0   95.0    3     5219.780220
# 337  Akshaya Nagar      2 BHK      1100.0   2.0   48.0    2     4363.636364
# 338  Akshaya Nagar      3 BHK      1896.0   3.0  102.0    3     5379.746835
# 339  Akshaya Nagar      2 BHK      1300.0   2.0   66.0    2     5076.923077
# 340  Akshaya Nagar      2 BHK      1225.0   2.0   68.0    2     5551.020408
# 341  Akshaya Nagar      2 BHK      1179.0   2.0   51.0    2     4325.699746
# 342  Akshaya Nagar      3 BHK      1421.0   2.0   73.0    3     5137.227305
# 343  Akshaya Nagar      3 BHK      1893.0   4.0   95.0    3     5018.489171
# 344  Akshaya Nagar      2 BHK       900.0   2.0   45.0    2     5000.000000
#        location   size  total_sqft  bath   price  bhk  price_per_sqft
# 345  Ambalipura  2 BHK      1105.0   2.0   75.00    2     6787.330317
# 346  Ambalipura  3 BHK      1800.0   3.0  110.00    3     6111.111111
# 347  Ambalipura  2 BHK      1150.0   2.0   80.00    2     6956.521739
# 348  Ambalipura  2 BHK      1250.0   2.0   66.25    2     5300.000000
# 349  Ambalipura  2 BHK      1332.0   2.0   79.00    2     5930.930931
# 350  Ambalipura  3 BHK      1730.0   3.0  120.00    3     6936.416185
# 351  Ambalipura  3 BHK      3500.0   3.0  198.00    3     5657.142857
# 352  Ambalipura  2 BHK      1230.0   2.0   66.25    2     5386.178862
# 353  Ambalipura  2 BHK      1351.0   2.0   77.00    2     5699.481865
# 354  Ambalipura  4 BHK      2550.0   4.0  149.00    4     5843.137255
# 355  Ambalipura  3 BHK      1817.0   3.0  102.00    3     5613.648872
# 356  Ambalipura  4 BHK      2750.0   4.0  142.00    4     5163.636364
# 357  Ambalipura  2 BHK      1303.0   2.0   80.00    2     6139.677667
# 358  Ambalipura  3 BHK      1607.0   2.0  112.00    3     6969.508401
# 359  Ambalipura  1 BHK       770.0   1.0   43.82    1     5690.909091
# 360  Ambalipura  2 BHK      1700.0   2.0   76.00    2     4470.588235
# 361  Ambalipura  2 BHK      1060.0   2.0   58.50    2     5518.867925
# 362  Ambalipura  3 BHK      1650.0   3.0  100.00    3     6060.606061
# 363  Ambalipura  3 BHK      1607.0   2.0  112.00    3     6969.508401
# 364  Ambalipura  2 BHK      1198.0   2.0   80.00    2     6677.796327
#            location       size  total_sqft  bath  price  bhk  price_per_sqft
# 365  Ambedkar Nagar      3 BHK      1935.0   4.0  130.0    3     6718.346253
# 366  Ambedkar Nagar      2 BHK      1424.0   2.0   90.0    2     6320.224719
# 367  Ambedkar Nagar      3 BHK      2225.0   4.0  169.0    3     7595.505618
# 368  Ambedkar Nagar      3 BHK      1862.0   3.0  120.0    3     6444.683136
# 369  Ambedkar Nagar      3 BHK      1850.0   4.0  139.0    3     7513.513514
# 370  Ambedkar Nagar      3 BHK      1936.0   4.0  126.0    3     6508.264463
# 371  Ambedkar Nagar      3 BHK      1862.0   3.0  119.0    3     6390.977444
# 372  Ambedkar Nagar      2 BHK      1424.0   2.0   90.0    2     6320.224719
# 373  Ambedkar Nagar      3 BHK      2150.0   4.0  125.0    3     5813.953488
# 374  Ambedkar Nagar      4 BHK      3530.0   4.0  290.0    4     8215.297450
# 375  Ambedkar Nagar      3 BHK      1856.0   3.0  120.0    3     6465.517241
# 376  Ambedkar Nagar      3 BHK      1852.0   3.0  130.0    3     7019.438445
# 377  Ambedkar Nagar      3 BHK      1850.0   4.0  120.0    3     6486.486486
# 378  Ambedkar Nagar      2 BHK      1367.0   2.0   86.0    2     6291.148500
# 379  Ambedkar Nagar  4 Bedroom      3565.0   4.0  255.0    4     7152.875175
# 380  Ambedkar Nagar      2 BHK      1409.0   2.0   95.0    2     6742.370476
# 381  Ambedkar Nagar      3 BHK      1950.0   4.0  120.0    3     6153.846154
# 382  Ambedkar Nagar      3 BHK      1921.0   4.0  129.0    3     6715.252473
# 383  Ambedkar Nagar      3 BHK      1920.0   4.0  121.0    3     6302.083333
# 384  Ambedkar Nagar      3 BHK      1935.0   4.0  125.0    3     6459.948320
# 385  Ambedkar Nagar      3 BHK      1852.0   4.0  122.0    3     6587.473002
# 386  Ambedkar Nagar      3 BHK      1950.0   4.0  120.0    3     6153.846154
# 387  Ambedkar Nagar      3 BHK      1852.0   3.0  125.0    3     6749.460043
# 388  Ambedkar Nagar      3 BHK      1850.0   4.0  121.0    3     6540.540541
# 389  Ambedkar Nagar      2 BHK      1425.0   2.0   94.0    2     6596.491228
# 390  Ambedkar Nagar      3 BHK      2395.0   4.0  150.0    3     6263.048017
#          location       size  total_sqft  bath  price  bhk  price_per_sqft
# 391  Amruthahalli      2 BHK       900.0   2.0   40.0    2     4444.444444
# 392  Amruthahalli      2 BHK      1200.0   2.0   55.0    2     4583.333333
# 393  Amruthahalli  3 Bedroom      1900.0   3.0  135.0    3     7105.263158
# 394  Amruthahalli      2 BHK       924.0   2.0   45.0    2     4870.129870
# 395  Amruthahalli      2 BHK       900.0   2.0   60.0    2     6666.666667
# 396  Amruthahalli      2 BHK      1100.0   2.0   45.0    2     4090.909091
# 397  Amruthahalli      2 BHK      1200.0   2.0   55.0    2     4583.333333
# 398  Amruthahalli      3 BHK      1350.0   2.0   63.0    3     4666.666667
# 399  Amruthahalli      3 BHK      1605.0   3.0   65.0    3     4049.844237
# 400  Amruthahalli      3 BHK      1700.0   3.0   77.0    3     4529.411765
# 401  Amruthahalli      3 BHK      1450.0   2.0   85.0    3     5862.068966
# 402  Amruthahalli      2 BHK      1200.0   2.0   55.0    2     4583.333333
# 403  Amruthahalli      2 BHK      1250.0   2.0   79.0    2     6320.000000
# 404  Amruthahalli      2 BHK      1190.0   2.0   50.0    2     4201.680672
# 405  Amruthahalli      2 BHK      1202.0   2.0   65.0    2     5407.653910
# 406  Amruthahalli      2 BHK      1340.0   2.0   75.0    2     5597.014925
# 407  Amruthahalli      3 BHK      2650.0   4.0  175.0    3     6603.773585
# 408  Amruthahalli      3 BHK      1450.0   2.0   90.0    3     6206.896552
# 409  Amruthahalli      2 BHK      1025.0   2.0   42.0    2     4097.560976
# 410  Amruthahalli      1 BHK       485.0   1.0   19.5    1     4020.618557
#        location       size  total_sqft  bath  price  bhk  price_per_sqft
# 411  Anandapura      2 BHK      1167.0   2.0  43.76    2     3749.785775
# 412  Anandapura  2 Bedroom      1000.0   2.0  55.00    2     5500.000000
# 413  Anandapura      2 BHK      1141.0   2.0  42.79    2     3750.219106
# 414  Anandapura      3 BHK      1576.0   3.0  59.10    3     3750.000000
# 415  Anandapura  2 Bedroom      1200.0   2.0  67.00    2     5583.333333
# 416  Anandapura  2 Bedroom      1200.0   2.0  58.00    2     4833.333333
# 417  Anandapura      2 BHK      1151.0   2.0  43.10    2     3744.569939
# 418  Anandapura      2 BHK      1141.0   2.0  42.75    2     3746.713409
# 419  Anandapura  2 Bedroom       900.0   2.0  48.00    2     5333.333333
# 420  Anandapura  4 Bedroom      1749.0   4.0  90.00    4     5145.797599
# 421  Anandapura      2 BHK      1151.0   2.0  42.90    2     3727.193745
# 422  Anandapura      3 BHK      1576.0   3.0  58.00    3     3680.203046
# 423  Anandapura      2 BHK      1250.0   2.0  45.00    2     3600.000000
# 424  Anandapura      2 BHK      1151.0   2.0  43.16    2     3749.782798
# 425  Anandapura  2 Bedroom      1200.0   2.0  58.00    2     4833.333333
# 426  Anandapura  3 Bedroom      1200.0   2.0  66.00    3     5500.000000
# 427  Anandapura  3 Bedroom      1415.0   2.0  74.00    3     5229.681979
# 428  Anandapura      2 BHK      1200.0   2.0  50.00    2     4166.666667
# 429  Anandapura      2 BHK      1141.0   2.0  50.00    2     4382.120947
# 430  Anandapura      3 BHK      1576.0   3.0  58.70    3     3724.619289
#          location   size  total_sqft  bath  price  bhk  price_per_sqft
# 431  Ananth Nagar  1 BHK       500.0   1.0  14.00    1     2800.000000
# 432  Ananth Nagar  2 BHK      1100.0   2.0  31.50    2     2863.636364
# 433  Ananth Nagar  2 BHK       982.0   2.0  24.55    2     2500.000000
# 434  Ananth Nagar  1 BHK       500.0   2.0  14.00    1     2800.000000
# 435  Ananth Nagar  2 BHK       900.0   2.0  22.50    2     2500.000000
# 436  Ananth Nagar  2 BHK       908.0   2.0  26.00    2     2863.436123
# 437  Ananth Nagar  2 BHK       870.0   2.0  36.00    2     4137.931034
# 438  Ananth Nagar  2 BHK       937.0   2.0  35.00    2     3735.325507
# 439  Ananth Nagar  2 BHK       960.0   2.0  37.00    2     3854.166667
# 440  Ananth Nagar  1 BHK       500.0   1.0  14.00    1     2800.000000
# 441  Ananth Nagar  2 BHK      1000.0   2.0  29.70    2     2970.000000
# 442  Ananth Nagar  2 BHK       850.0   2.0  25.99    2     3057.647059
# 443  Ananth Nagar  2 BHK       902.0   2.0  25.26    2     2800.443459
# 444  Ananth Nagar  3 BHK      1470.0   3.0  54.00    3     3673.469388
# 445  Ananth Nagar  2 BHK       810.0   2.0  25.50    2     3148.148148
# 446  Ananth Nagar  2 BHK       890.0   2.0  27.00    2     3033.707865
# 447  Ananth Nagar  2 BHK      1200.0   2.0  36.00    2     3000.000000
# 448  Ananth Nagar  3 BHK      1319.0   3.0  37.75    3     2862.016679
# 449  Ananth Nagar  3 BHK      1319.0   3.0  42.00    3     3184.230478
# 450  Ananth Nagar  2 BHK      1000.0   2.0  25.00    2     2500.000000
# 451  Ananth Nagar  2 BHK       902.0   2.0  25.00    2     2771.618625
# 452  Ananth Nagar  2 BHK       930.0   2.0  25.99    2     2794.623656
# 453  Ananth Nagar  2 BHK      1074.0   2.0  26.85    2     2500.000000
# 454  Ananth Nagar  1 BHK       500.0   1.0  14.00    1     2800.000000
# 455  Ananth Nagar  2 BHK      1010.0   2.0  38.00    2     3762.376238
# 456  Ananth Nagar  2 BHK       992.0   2.0  24.80    2     2500.000000
#     location       size  total_sqft  bath  price  bhk  price_per_sqft
# 457   Anekal  2 Bedroom      1200.0   1.0   36.0    2     3000.000000
# 458   Anekal      2 BHK       656.0   2.0   22.0    2     3353.658537
# 459   Anekal      2 BHK       620.0   2.0   22.0    2     3548.387097
# 460   Anekal      1 BHK       600.0   1.0   16.5    1     2750.000000
# 461   Anekal      2 BHK       925.0   2.0   40.0    2     4324.324324
# 462   Anekal      1 BHK       530.0   1.0   18.0    1     3396.226415
# 463   Anekal  3 Bedroom      1800.0   3.0   68.0    3     3777.777778
# 464   Anekal  2 Bedroom      1200.0   1.0   36.0    2     3000.000000
# 465   Anekal       1 RK       351.0   1.0   16.0    1     4558.404558
# 466   Anekal      2 BHK      1035.0   2.0   38.3    2     3700.483092
# 467   Anekal      2 BHK       888.0   2.0   34.0    2     3828.828829
# 468   Anekal  2 Bedroom      1200.0   2.0   36.1    2     3008.333333
# 469   Anekal      2 BHK       700.0   1.0   19.4    2     2771.428571
# 470   Anekal  2 Bedroom      1200.0   1.0   36.0    2     3000.000000
# 471   Anekal  4 Bedroom      1200.0   2.0   36.0    4     3000.000000
# 472   Anekal      2 BHK       766.0   2.0   28.0    2     3655.352480
# 473   Anekal      3 BHK       967.0   2.0   45.0    3     4653.567735
# 474   Anekal      2 BHK       620.0   1.0   23.5    2     3790.322581
# 475   Anekal      3 BHK      1150.0   3.0   45.0    3     3913.043478
# 476   Anekal  2 Bedroom      1200.0   1.0   36.0    2     3000.000000
# 477   Anekal  2 Bedroom      1200.0   1.0   36.0    2     3000.000000
# 478   Anekal      1 BHK       400.0   1.0   11.5    1     2875.000000
# 479   Anekal      1 BHK       456.0   1.0   15.0    1     3289.473684
# 480   Anekal  2 Bedroom      1200.0   1.0   36.0    2     3000.000000
# 481   Anekal  2 Bedroom      1200.0   1.0   36.0    2     3000.000000
# 482   Anekal  3 Bedroom      2400.0   4.0   95.0    3     3958.333333
# 483   Anekal  2 Bedroom      1200.0   2.0   36.1    2     3008.333333
# 484   Anekal  2 Bedroom      1200.0   2.0   36.1    2     3008.333333
# 485   Anekal      2 BHK       680.0   1.0   21.0    2     3088.235294
# 486   Anekal      1 BHK       420.0   1.0   12.5    1     2976.190476
# 487   Anekal      2 BHK       614.0   1.0   28.0    2     4560.260586
# 488   Anekal      2 BHK      1140.0   2.0   52.0    2     4561.403509
# 489   Anekal      2 BHK       625.0   1.0   25.0    2     4000.000000
#        location       size  total_sqft  bath   price  bhk  price_per_sqft
# 490  Anjanapura      4 BHK      1850.0   4.0   86.00    4     4648.648649
# 491  Anjanapura      2 BHK      1070.0   2.0   39.00    2     3644.859813
# 492  Anjanapura  3 Bedroom      1500.0   3.0  121.00    3     8066.666667
# 493  Anjanapura      2 BHK      1070.0   2.0   37.00    2     3457.943925
# 494  Anjanapura      2 BHK       950.0   2.0   40.00    2     4210.526316
# 495  Anjanapura      3 BHK      1280.0   2.0   45.00    3     3515.625000
# 496  Anjanapura      2 BHK       710.0   2.0   25.00    2     3521.126761
# 497  Anjanapura      3 BHK      1347.0   2.0   37.72    3     2800.296956
# 498  Anjanapura      2 BHK       950.0   2.0   32.00    2     3368.421053
# 499  Anjanapura      4 BHK      1800.0   4.0   55.00    4     3055.555556
# 500  Anjanapura      3 BHK      1843.0   3.0   87.54    3     4749.864352
# 501  Anjanapura      2 BHK      1076.0   2.0   30.13    2     2800.185874
# 502  Anjanapura      2 BHK       950.0   2.0   30.00    2     3157.894737
#       location       size  total_sqft  bath  price  bhk  price_per_sqft
# 503  Ardendale      3 BHK     1750.00   3.0  100.0    3     5714.285714
# 504  Ardendale      4 BHK     3198.00   4.0  200.0    4     6253.908693
# 505  Ardendale      4 BHK     2422.00   4.0  160.0    4     6606.110652
# 506  Ardendale      3 BHK     1750.00   3.0  100.0    3     5714.285714
# 507  Ardendale  4 Bedroom     3200.00   4.0  205.0    4     6406.250000
# 508  Ardendale      3 BHK     1728.00   3.0   95.0    3     5497.685185
# 509  Ardendale      4 BHK     2062.00   3.0  140.0    4     6789.524733
# 510  Ardendale      3 BHK     1732.46   3.0   92.0    3     5310.367916
# 511  Ardendale      4 BHK     2062.00   3.0  150.0    4     7274.490786
# 512  Ardendale      4 BHK     2800.00   4.0  140.0    4     5000.000000
# 513  Ardendale      2 BHK     1224.00   2.0   70.0    2     5718.954248
# 514  Ardendale      3 BHK     1777.26   3.0  105.0    3     5907.970696
# 515  Ardendale      3 BHK     1650.00   3.0   82.0    3     4969.696970
# 516  Ardendale      4 BHK     2062.00   3.0  140.0    4     6789.524733
# 517  Ardendale      3 BHK     1650.00   3.0   82.0    3     4969.696970
# 518  Ardendale      2 BHK     1224.00   2.0   67.0    2     5473.856209
# 519  Ardendale      3 BHK     1723.00   3.0   95.0    3     5513.639002
# 520  Ardendale      3 BHK     1777.26   3.0   89.0    3     5007.708495
# 521  Ardendale      3 BHK     1777.26   3.0   92.0    3     5176.507658
#     location   size  total_sqft  bath  price  bhk  price_per_sqft
# 522  Arekere  3 BHK      2060.0   3.0  140.0    3     6796.116505
# 523  Arekere  2 BHK       920.0   2.0   40.0    2     4347.826087
# 524  Arekere  3 BHK      1740.0   2.0   95.0    3     5459.770115
# 525  Arekere  2 BHK      1190.0   2.0   55.0    2     4621.848739
# 526  Arekere  1 BHK       600.0   1.0   28.0    1     4666.666667
# 527  Arekere  3 BHK      2072.0   3.0  108.0    3     5212.355212
# 528  Arekere  2 BHK      1100.0   2.0   55.0    2     5000.000000
# 529  Arekere  2 BHK       900.0   2.0   50.0    2     5555.555556
# 530  Arekere  4 BHK      2710.0   6.0  142.0    4     5239.852399
# 531  Arekere  2 BHK      1240.0   2.0   60.0    2     4838.709677
# 532  Arekere  2 BHK       900.0   2.0   44.5    2     4944.444444
#      location       size  total_sqft  bath   price  bhk  price_per_sqft
# 533  Attibele      1 BHK       450.0   1.0   11.00    1     2444.444444
# 534  Attibele  4 Bedroom      1600.0   4.0   52.80    4     3300.000000
# 535  Attibele      2 BHK       656.0   2.0   25.00    2     3810.975610
# 536  Attibele      1 BHK       400.0   1.0   11.00    1     2750.000000
# 537  Attibele      1 BHK       400.0   1.0   12.00    1     3000.000000
# 538  Attibele      1 BHK       400.0   1.0   14.00    1     3500.000000
# 539  Attibele      1 BHK       500.0   1.0   17.00    1     3400.000000
# 540  Attibele  4 Bedroom      2168.0   4.0   95.00    4     4381.918819
# 541  Attibele      1 BHK       395.0   1.0   10.25    1     2594.936709
# 542  Attibele      1 BHK       420.0   1.0   17.00    1     4047.619048
# 543  Attibele      3 BHK      1639.0   2.0   40.98    3     2500.305064
# 544  Attibele      1 BHK       418.0   1.0   12.00    1     2870.813397
# 545  Attibele      2 BHK      1200.0   2.0   42.00    2     3500.000000
# 546  Attibele      1 BHK       400.0   1.0   10.00    1     2500.000000
# 547  Attibele      2 BHK       695.0   1.0   25.00    2     3597.122302
# 548  Attibele      2 BHK       850.0   1.0   25.00    2     2941.176471
# 549  Attibele  3 Bedroom      2400.0   3.0  120.00    3     5000.000000
# 550  Attibele      1 BHK       450.0   1.0   12.50    1     2777.777778
# 551  Attibele      2 BHK       995.0   1.0   24.88    2     2500.502513
# 552  Attibele      2 BHK       900.0   1.0   25.00    2     2777.777778
# 553  Attibele      2 BHK      1174.0   2.0   29.35    2     2500.000000
# 554  Attibele      1 BHK       782.0   1.0   19.55    1     2500.000000
# 555  Attibele      2 BHK      1175.0   2.0   29.38    2     2500.425532
# 556  Attibele      2 BHK       656.0   2.0   25.00    2     3810.975610
# 557  Attibele      1 BHK       400.0   1.0   11.50    1     2875.000000
# 558  Attibele      1 BHK       460.0   1.0   13.00    1     2826.086957
# 559  Attibele      1 BHK       418.0   2.0   11.50    1     2751.196172
# 560  Attibele  2 Bedroom      1000.0   2.0   42.00    2     4200.000000
# 561  Attibele      1 BHK       550.0   1.0   11.50    1     2090.909091
# 562  Attibele      2 BHK       996.0   2.0   24.90    2     2500.000000
# 563  Attibele      1 BHK       410.0   1.0   10.00    1     2439.024390
# 564  Attibele  3 Bedroom      1700.0   3.0   65.00    3     3823.529412
# 565  Attibele      1 BHK       400.0   1.0   10.25    1     2562.500000
# 566  Attibele      2 BHK       656.0   2.0   25.00    2     3810.975610
# 567  Attibele  3 Bedroom      1500.0   3.0   90.00    3     6000.000000
# 568  Attibele      1 BHK       520.0   1.0   15.00    1     2884.615385
#         location       size  total_sqft  bath  price  bhk  price_per_sqft
# 569  BEML Layout      2 BHK      1060.0   2.0   55.0    2     5188.679245
# 570  BEML Layout      3 BHK      2000.0   3.0   85.0    3     4250.000000
# 571  BEML Layout      2 BHK       999.0   2.0   45.0    2     4504.504505
# 572  BEML Layout  5 Bedroom      2400.0   4.0  225.0    5     9375.000000
# 573  BEML Layout      3 BHK      2000.0   2.0   85.0    3     4250.000000
# 574  BEML Layout      2 BHK      1194.0   2.0   65.0    2     5443.886097
# 575  BEML Layout      2 BHK      1200.0   2.0   67.0    2     5583.333333
# 576  BEML Layout  2 Bedroom      2400.0   2.0  228.0    2     9500.000000
# 577  BEML Layout      3 BHK      2000.0   3.0   85.0    3     4250.000000
# 578  BEML Layout      3 BHK      2000.0   3.0   85.0    3     4250.000000
# 579  BEML Layout      2 BHK      1194.0   2.0   65.0    2     5443.886097
#           location       size  total_sqft  bath  price  bhk  price_per_sqft
# 580  BTM 2nd Stage  3 Bedroom      1260.0   5.0  185.0    3    14682.539683
# 581  BTM 2nd Stage      2 BHK       950.0   2.0   52.0    2     5473.684211
# 582  BTM 2nd Stage      3 BHK      1850.0   3.0  170.0    3     9189.189189
# 583  BTM 2nd Stage      2 BHK      1200.0   2.0   80.0    2     6666.666667
# 584  BTM 2nd Stage      2 BHK      1274.0   2.0   70.0    2     5494.505495
# 585  BTM 2nd Stage      3 BHK      1250.0   3.0   50.0    3     4000.000000
# 586  BTM 2nd Stage      2 BHK      1070.0   2.0   48.0    2     4485.981308
# 587  BTM 2nd Stage      2 BHK      1280.0   2.0   80.0    2     6250.000000
# 588  BTM 2nd Stage      2 BHK      1100.0   2.0   70.0    2     6363.636364
# 589  BTM 2nd Stage      2 BHK      1000.0   2.0   58.0    2     5800.000000
# 590  BTM 2nd Stage  5 Bedroom      2990.0   5.0  416.0    5    13913.043478
# 591  BTM 2nd Stage      2 BHK      1265.0   2.0   55.0    2     4347.826087
# 592  BTM 2nd Stage      3 BHK      2200.0   3.0  220.0    3    10000.000000
# 593  BTM 2nd Stage      3 BHK      2780.0   4.0  325.0    3    11690.647482
# 594  BTM 2nd Stage  3 Bedroom      2400.0   2.0  360.0    3    15000.000000
# 595  BTM 2nd Stage      2 BHK       965.0   2.0   56.0    2     5803.108808
# 596  BTM 2nd Stage      2 BHK      1147.0   2.0   75.0    2     6538.796861
# 597  BTM 2nd Stage      3 BHK      1750.0   3.0  172.0    3     9828.571429
# 598  BTM 2nd Stage      2 BHK      1400.0   2.0   90.0    2     6428.571429
# 599  BTM 2nd Stage      2 BHK      1200.0   2.0   70.0    2     5833.333333
# 600  BTM 2nd Stage      2 BHK      1100.0   2.0   47.0    2     4272.727273
# 601  BTM 2nd Stage      2 BHK       930.0   2.0   46.0    2     4946.236559
# 602  BTM 2nd Stage      3 BHK      1265.0   2.0   55.0    3     4347.826087
# 603  BTM 2nd Stage      3 BHK      2500.0   3.0  345.0    3    13800.000000
#        location       size  total_sqft  bath   price  bhk  price_per_sqft
# 604  BTM Layout      2 BHK      1150.0   2.0   63.00    2     5478.260870
# 605  BTM Layout  6 Bedroom      3300.0   6.0  165.00    6     5000.000000
# 606  BTM Layout      3 BHK      1450.0   2.0   81.00    3     5586.206897
# 607  BTM Layout      3 BHK      1776.0   2.0   75.00    3     4222.972973
# 608  BTM Layout      3 BHK      1458.0   3.0   79.00    3     5418.381344
# 609  BTM Layout      2 BHK       935.0   2.0   51.50    2     5508.021390
# 610  BTM Layout      2 BHK      1020.0   2.0   46.50    2     4558.823529
# 611  BTM Layout      3 BHK      1600.0   3.0  112.00    3     7000.000000
# 612  BTM Layout      3 BHK      1300.0   2.0   75.00    3     5769.230769
# 613  BTM Layout      3 BHK      1540.0   2.0   78.00    3     5064.935065
# 614  BTM Layout      1 BHK       450.0   1.0   20.00    1     4444.444444
# 615  BTM Layout      2 BHK      1196.0   2.0   56.81    2     4750.000000
# 616  BTM Layout      3 BHK      1470.0   2.0   99.00    3     6734.693878
#          location   size  total_sqft  bath  price  bhk  price_per_sqft
# 617  Babusapalaya  3 BHK      1358.0   2.0  43.40    3     3195.876289
# 618  Babusapalaya  3 BHK      1213.0   2.0  41.39    3     3412.201154
# 619  Babusapalaya  3 BHK      1611.0   2.0  66.00    3     4096.834264
# 620  Babusapalaya  3 BHK      1167.0   2.0  39.98    3     3425.878320
# 621  Babusapalaya  3 BHK      1675.0   3.0  75.00    3     4477.611940
# 622  Babusapalaya  2 BHK      1141.0   2.0  46.00    2     4031.551271
# 623  Babusapalaya  2 BHK      1500.0   2.0  57.00    2     3800.000000
# 624  Babusapalaya  3 BHK      1453.0   2.0  43.59    3     3000.000000
# 625  Babusapalaya  2 BHK      1050.0   2.0  45.00    2     4285.714286
# 626  Babusapalaya  2 BHK      1141.0   2.0  45.90    2     4022.787029
# 627  Babusapalaya  3 BHK      1358.0   2.0  43.10    3     3173.784978
# 628  Babusapalaya  3 BHK      1230.0   3.0  53.00    3     4308.943089
# 629  Babusapalaya  2 BHK      1105.0   2.0  40.00    2     3619.909502
# 630  Babusapalaya  3 BHK      1410.0   2.0  65.00    3     4609.929078
# 631  Babusapalaya  2 BHK      1450.0   2.0  55.99    2     3861.379310
# 632  Babusapalaya  2 BHK      1100.0   2.0  38.00    2     3454.545455
# 633  Babusapalaya  3 BHK      1213.0   2.0  36.37    3     2998.351195
# 634  Babusapalaya  2 BHK      1061.0   2.0  33.84    2     3189.443921
# 635  Babusapalaya  2 BHK      1061.0   2.0  38.95    2     3671.065033
# 636  Babusapalaya  2 BHK      1061.0   2.0  34.00    2     3204.524034
# 637  Babusapalaya  2 BHK      1245.0   2.0  58.00    2     4658.634538
#            location   size  total_sqft  bath   price  bhk  price_per_sqft
# 638  Badavala Nagar  3 BHK      1494.0   2.0   94.55    3     6328.647925
# 639  Badavala Nagar  2 BHK      1274.0   2.0   81.00    2     6357.927786
# 640  Badavala Nagar  3 BHK      1842.0   3.0  115.00    3     6243.213898
# 641  Badavala Nagar  3 BHK      1494.0   2.0   94.55    3     6328.647925
# 642  Badavala Nagar  2 BHK      1274.0   2.0   81.00    2     6357.927786
# 643  Badavala Nagar  3 BHK      1494.0   2.0   94.55    3     6328.647925
# 644  Badavala Nagar  3 BHK      1842.0   3.0  115.00    3     6243.213898
# 645  Badavala Nagar  3 BHK      1842.0   3.0  115.00    3     6243.213898
# 646  Badavala Nagar  3 BHK      1842.0   3.0  115.00    3     6243.213898
#      location   size  total_sqft  bath   price  bhk  price_per_sqft
# 647  Balagere  2 BHK     1210.00   2.0  80.900    2     6685.950413
# 648  Balagere  2 BHK     1210.00   2.0  72.000    2     5950.413223
# 649  Balagere  2 BHK     1205.00   2.0  78.500    2     6514.522822
# 650  Balagere  1 BHK      790.50   1.0  41.900    1     5300.442758
# 651  Balagere  2 BHK     1145.00   2.0  65.000    2     5676.855895
# 652  Balagere  2 BHK     1012.00   2.0  54.590    2     5394.268775
# 653  Balagere  2 BHK     1020.07   2.0  68.380    2     6703.461527
# 654  Balagere  2 BHK     1205.47   2.0  81.000    2     6719.370868
# 655  Balagere  2 BHK     1007.00   2.0  65.000    2     6454.816286
# 656  Balagere  2 BHK     1205.00   2.0  70.000    2     5809.128631
# 657  Balagere  2 BHK     1210.00   2.0  74.000    2     6115.702479
# 658  Balagere  2 BHK     1210.00   2.0  83.000    2     6859.504132
# 659  Balagere  1 BHK      675.00   1.0  45.000    1     6666.666667
# 660  Balagere  1 BHK      656.00   1.0  43.000    1     6554.878049
# 661  Balagere  2 BHK     1012.00   2.0  54.590    2     5394.268775
# 662  Balagere  2 BHK     1012.00   2.0  64.000    2     6324.110672
# 663  Balagere  2 BHK     1007.00   2.0  62.000    2     6156.901688
# 664  Balagere  2 BHK     1007.00   2.0  67.000    2     6653.426018
# 665  Balagere  2 BHK     1007.00   2.0  66.000    2     6554.121152
# 666  Balagere  2 BHK     1205.00   2.0  63.860    2     5299.585062
# 667  Balagere  2 BHK     1012.00   2.0  53.580    2     5294.466403
# 668  Balagere  1 BHK      645.00   1.0  34.180    1     5299.224806
# 669  Balagere  2 BHK     1007.00   2.0  53.000    2     5263.157895
# 670  Balagere  2 BHK     1210.00   2.0  69.000    2     5702.479339
# 671  Balagere  1 BHK      790.50   1.0  42.295    1     5350.411132
# 672  Balagere  2 BHK     1012.00   2.0  65.000    2     6422.924901
# 673  Balagere  1 BHK      656.00   1.0  38.770    1     5910.060976
# 674  Balagere  1 BHK      645.00   1.0  39.000    1     6046.511628
# 675  Balagere  1 BHK      645.00   1.0  41.000    1     6356.589147
# 676  Balagere  2 BHK     1210.00   2.0  82.000    2     6776.859504
# 677  Balagere  1 BHK      656.00   1.0  34.770    1     5300.304878
# 678  Balagere  2 BHK     1205.00   2.0  73.870    2     6130.290456
# 679  Balagere  2 BHK     1012.00   2.0  70.000    2     6916.996047
# 680  Balagere  2 BHK     1007.00   2.0  68.000    2     6752.730884
# 681  Balagere  2 BHK     1205.00   2.0  67.000    2     5560.165975
# 682  Balagere  2 BHK     1205.00   2.0  79.000    2     6556.016598
# 683  Balagere  2 BHK     1012.00   2.0  68.000    2     6719.367589
#          location   size  total_sqft  bath   price  bhk  price_per_sqft
# 684  Banashankari  3 BHK      1200.0   2.0   42.00    3     3500.000000
# 685  Banashankari  2 BHK      1077.0   2.0   37.64    2     3494.893222
# ...
# 7119  Vidyaranyapura      3 BHK      1440.0   2.0   70.0    3     4861.111111
# 7120  Vidyaranyapura      2 BHK      1100.0   2.0   54.0    2     4909.090909
# 7121  Vidyaranyapura      2 BHK      1000.0   2.0   35.0    2     3500.000000
# 7122  Vidyaranyapura      3 BHK      1560.0   3.0   68.0    3     4358.974359
# 7123  Vidyaranyapura      2 BHK      1120.0   2.0   70.0    2     6250.000000
# 7124  Vidyaranyapura      2 BHK       945.0   2.0   40.0    2     4232.804233
# 7125  Vidyaranyapura      2 BHK      1100.0   2.0   54.0    2     4909.090909
# 7126  Vidyaranyapura      3 BHK      1200.0   2.0   65.0    3     5416.666667
# 7127  Vidyaranyapura      2 BHK      1200.0   2.0   52.0    2     4333.333333
# 7128  Vidyaranyapura      2 BHK      1050.0   2.0   50.0    2     4761.904762
# 7129  Vidyaranyapura      2 BHK      1188.0   2.0   50.0    2     4208.754209
# 7130  Vidyaranyapura      3 BHK      1100.0   2.0   75.0    3     6818.181818
# 7131  Vidyaranyapura      3 BHK      1100.0   2.0   72.0    3     6545.454545
# 7132  Vidyaranyapura      4 BHK      2400.0   5.0  135.0    4     5625.000000
# 7133  Vidyaranyapura      2 BHK      1100.0   2.0   41.0    2     3727.272727
# 7134  Vidyaranyapura      2 BHK      1200.0   2.0   60.5    2     5041.666667
# 7135  Vidyaranyapura      2 BHK      1200.0   2.0   42.0    2     3500.000000
#          location       size  total_sqft  bath   price  bhk  price_per_sqft
# 7136  Vijayanagar      3 BHK      1704.0   3.0  110.00    3     6455.399061
# 7137  Vijayanagar      3 BHK      1933.0   3.0  129.00    3     6673.564408
# 7138  Vijayanagar      3 BHK      1500.0   3.0   75.50    3     5033.333333
# 7139  Vijayanagar      3 BHK      1450.0   3.0  100.00    3     6896.551724
# 7140  Vijayanagar      3 BHK      1580.0   2.0  134.00    3     8481.012658
# 7141  Vijayanagar      3 BHK      1826.0   3.0  121.00    3     6626.506024
# 7142  Vijayanagar      3 BHK      1739.0   3.0  116.00    3     6670.500288
# 7143  Vijayanagar      3 BHK      1490.0   3.0  100.00    3     6711.409396
# 7144  Vijayanagar      2 BHK      1180.0   2.0   65.00    2     5508.474576
# 7145  Vijayanagar      1 BHK       606.0   1.0   34.78    1     5739.273927
# 7146  Vijayanagar      2 BHK      1352.0   2.0   68.00    2     5029.585799
# 7147  Vijayanagar      3 BHK      1527.0   3.0  115.00    3     7531.106745
# 7148  Vijayanagar      2 BHK       989.0   2.0   60.00    2     6066.734075
# 7149  Vijayanagar      3 BHK      1520.0   2.0  103.00    3     6776.315789
# 7150  Vijayanagar      3 BHK      1749.0   3.0  117.00    3     6689.536878
# 7151  Vijayanagar      2 BHK      1046.0   2.0   75.00    2     7170.172084
# 7152  Vijayanagar      1 BHK       606.0   1.0   40.00    1     6600.660066
# 7153  Vijayanagar      2 BHK      1200.0   2.0   62.00    2     5166.666667
# 7154  Vijayanagar      3 BHK      1300.0   2.0   75.00    3     5769.230769
# 7155  Vijayanagar      3 BHK      1484.0   3.0   79.19    3     5336.253369
# 7156  Vijayanagar      3 BHK      1760.0   3.0  140.00    3     7954.545455
# 7157  Vijayanagar      3 BHK      2047.0   3.0  136.00    3     6643.869077
# 7158  Vijayanagar      3 BHK      1200.0   2.0   75.00    3     6250.000000
# 7159  Vijayanagar      2 BHK      1178.0   2.0   82.00    2     6960.950764
# 7160  Vijayanagar      2 BHK       864.0   2.0   45.00    2     5208.333333
# 7161  Vijayanagar  4 Bedroom      2100.0   6.0  252.00    4    12000.000000
# 7162  Vijayanagar      2 BHK       920.0   2.0   60.00    2     6521.739130
# 7163  Vijayanagar      2 BHK      1019.0   2.0   58.00    2     5691.854760
# 7164  Vijayanagar  5 Bedroom      2400.0   6.0  125.00    5     5208.333333
# 7165  Vijayanagar      2 BHK      1180.0   2.0   86.00    2     7288.135593
# 7166  Vijayanagar      2 BHK      1046.0   2.0   49.06    2     4690.248566
# 7167  Vijayanagar  1 Bedroom      2400.0   2.0  230.00    1     9583.333333
# 7168  Vijayanagar      1 BHK       492.0   1.0   40.00    1     8130.081301
# 7169  Vijayanagar      3 BHK      1375.0   2.0   75.00    3     5454.545455
#                   location       size  total_sqft  bath  price  bhk  \
# 7170  Vishveshwarya Layout  1 Bedroom       750.0   1.0   30.0    1
# 7171  Vishveshwarya Layout      4 BHK      2000.0   4.0   75.0    4
# 7172  Vishveshwarya Layout      6 BHK      2100.0   6.0   92.0    6
# 7173  Vishveshwarya Layout  4 Bedroom      2000.0   3.0   90.0    4
#
#       price_per_sqft
# 7170     4000.000000
# 7171     3750.000000
# 7172     4380.952381
# 7173     4500.000000
#                 location   size  total_sqft  bath  price  bhk  price_per_sqft
# 7174  Vishwapriya Layout  2 BHK       820.0   2.0   30.0    2     3658.536585
# 7175  Vishwapriya Layout  2 BHK       770.0   2.0   30.0    2     3896.103896
# 7176  Vishwapriya Layout  2 BHK       910.0   2.0   36.0    2     3956.043956
# 7177  Vishwapriya Layout  2 BHK       890.0   2.0   37.0    2     4157.303371
#          location   size  total_sqft  bath  price  bhk  price_per_sqft
# 7178  Vittasandra  2 BHK      1404.0   2.0  71.00    2     5056.980057
# 7179  Vittasandra  2 BHK      1246.0   2.0  67.00    2     5377.207063
# 7180  Vittasandra  2 BHK      1404.0   2.0  69.30    2     4935.897436
# 7181  Vittasandra  2 BHK      1246.0   2.0  67.30    2     5401.284109
# 7182  Vittasandra  2 BHK      1246.0   2.0  64.50    2     5176.565008
# 7183  Vittasandra  2 BHK      1246.0   2.0  64.50    2     5176.565008
# 7184  Vittasandra  2 BHK      1246.0   2.0  68.00    2     5457.463884
# 7185  Vittasandra  3 BHK      1743.0   3.0  85.00    3     4876.649455
# 7186  Vittasandra  2 BHK      1238.0   2.0  67.00    2     5411.954766
# 7187  Vittasandra  2 BHK      1404.0   2.0  75.00    2     5341.880342
# 7188  Vittasandra  2 BHK      1246.0   2.0  65.00    2     5216.693419
# 7189  Vittasandra  2 BHK      1238.0   2.0  67.00    2     5411.954766
# 7190  Vittasandra  2 BHK      1246.0   2.0  67.40    2     5409.309791
# 7191  Vittasandra  2 BHK      1259.0   2.0  67.40    2     5353.455123
# 7192  Vittasandra  2 BHK      1404.0   2.0  68.80    2     4900.284900
# 7193  Vittasandra  2 BHK      1246.0   2.0  62.30    2     5000.000000
# 7194  Vittasandra  2 BHK      1246.0   2.0  63.00    2     5056.179775
# 7195  Vittasandra  2 BHK      1246.0   2.0  67.40    2     5409.309791
# 7196  Vittasandra  2 BHK      1246.0   2.0  65.40    2     5248.796148
# 7197  Vittasandra  3 BHK      1650.0   3.0  84.00    3     5090.909091
# 7198  Vittasandra  2 BHK      1238.0   2.0  67.32    2     5437.802908
# 7199  Vittasandra  2 BHK      1246.0   2.0  67.40    2     5409.309791
# 7200  Vittasandra  3 BHK      1650.0   3.0  85.00    3     5151.515152
# 7201  Vittasandra  2 BHK      1246.0   2.0  67.30    2     5401.284109
# 7202  Vittasandra  2 BHK      1404.0   2.0  70.00    2     4985.754986
# 7203  Vittasandra  2 BHK      1259.0   2.0  67.48    2     5359.809373
# 7204  Vittasandra  2 BHK      1404.0   2.0  75.00    2     5341.880342
# 7205  Vittasandra  3 BHK      1650.0   3.0  85.50    3     5181.818182
# 7206  Vittasandra  2 BHK      1246.0   2.0  67.00    2     5377.207063
# 7207  Vittasandra  3 BHK      1650.0   3.0  85.00    3     5151.515152
# 7208  Vittasandra  3 BHK      1650.0   3.0  85.50    3     5181.818182
# 7209  Vittasandra  2 BHK      1404.0   2.0  72.00    2     5128.205128
# 7210  Vittasandra  2 BHK      1246.0   2.0  67.50    2     5417.335474
# 7211  Vittasandra  2 BHK      1246.0   2.0  67.50    2     5417.335474
# 7212  Vittasandra  2 BHK      1404.0   2.0  70.00    2     4985.754986
# 7213  Vittasandra  2 BHK      1246.0   2.0  65.00    2     5216.693419
# 7214  Vittasandra  2 BHK      1246.0   2.0  67.40    2     5409.309791
# 7215  Vittasandra  3 BHK      1648.0   3.0  85.00    3     5157.766990
#         location       size  total_sqft  bath   price  bhk  price_per_sqft
# 7216  Whitefield      2 BHK      1170.0   2.0   38.00    2     3247.863248
# 7217  Whitefield      3 BHK      1800.0   2.0   70.00    3     3888.888889
# 7218  Whitefield      3 BHK      1610.0   3.0   81.00    3     5031.055901
# 7219  Whitefield      2 BHK      1459.0   2.0   94.82    2     6498.971899
# 7220  Whitefield      3 BHK      2010.0   3.0   91.00    3     4527.363184
# ...          ...        ...         ...   ...     ...  ...             ...
# 7696  Whitefield      3 BHK      1730.0   3.0  125.00    3     7225.433526
# 7697  Whitefield      3 BHK      1453.0   2.0   58.00    3     3991.741225
# 7698  Whitefield      1 BHK       877.0   1.0   59.00    1     6727.480046
# 7699  Whitefield      4 BHK      2856.0   5.0  154.50    4     5409.663866
# 7700  Whitefield  5 Bedroom      3453.0   4.0  231.00    5     6689.834926
#
# [485 rows x 7 columns]
#             location   size  total_sqft  bath  price  bhk  price_per_sqft
# 7701  Yelachenahalli  3 BHK      1400.0   2.0   55.0    3     3928.571429
# 7702  Yelachenahalli  3 BHK      1464.0   2.0  105.0    3     7172.131148
# 7703  Yelachenahalli  2 BHK      2400.0   1.0  150.0    2     6250.000000
# 7704  Yelachenahalli  3 BHK      1700.0   3.0  130.0    3     7647.058824
# 7705  Yelachenahalli  2 BHK      1080.0   2.0   55.0    2     5092.592593
# 7706  Yelachenahalli  2 BHK      1400.0   2.0   78.0    2     5571.428571
# 7707  Yelachenahalli  3 BHK      1330.0   3.0   73.5    3     5526.315789
# 7708  Yelachenahalli  2 BHK       800.0   1.0   30.0    2     3750.000000
# 7709  Yelachenahalli  2 BHK      1100.0   2.0   60.0    2     5454.545455
# 7710  Yelachenahalli  3 BHK      1365.0   2.0   72.0    3     5274.725275
# 7711  Yelachenahalli  2 BHK      1103.0   2.0   55.0    2     4986.400725
# 7712  Yelachenahalli  2 BHK      1000.0   2.0   50.0    2     5000.000000
#        location   size  total_sqft  bath  price  bhk  price_per_sqft
# 7713  Yelahanka  3 BHK      1600.0   2.0  75.00    3     4687.500000
# 7714  Yelahanka  2 BHK      1326.0   2.0  78.00    2     5882.352941
# 7715  Yelahanka  3 BHK      1282.0   2.0  48.70    3     3798.751950
# 7716  Yelahanka  2 BHK      1350.0   2.0  55.55    2     4114.814815
# 7717  Yelahanka  2 BHK      1035.0   2.0  45.00    2     4347.826087
# ...         ...    ...         ...   ...    ...  ...             ...
# 7879  Yelahanka  3 BHK      1282.0   2.0  48.72    3     3800.312012
# 7880  Yelahanka  2 BHK      1180.0   2.0  55.00    2     4661.016949
# 7881  Yelahanka  2 BHK      1267.0   3.0  78.00    2     6156.274665
# 7882  Yelahanka  2 BHK      1360.0   2.0  78.19    2     5749.264706
# 7883  Yelahanka  2 BHK      1025.0   2.0  44.00    2     4292.682927
#
# [171 rows x 7 columns]
#                 location       size  total_sqft  bath  price  bhk  \
# 7884  Yelahanka New Town      1 BHK       650.0   1.0   33.0    1
# 7885  Yelahanka New Town      1 BHK       500.0   1.0   20.0    1
# 7886  Yelahanka New Town      1 BHK       440.0   1.0   16.5    1
# 7887  Yelahanka New Town      3 BHK      1610.0   3.0   92.0    3
# 7888  Yelahanka New Town      3 BHK      1700.0   3.0   90.0    3
# 7889  Yelahanka New Town      1 BHK       650.0   1.0   20.0    1
# 7890  Yelahanka New Town      1 BHK       350.0   1.0   13.5    1
# 7891  Yelahanka New Town      3 BHK      1541.0   3.0   80.0    3
# 7892  Yelahanka New Town      2 BHK      1385.0   2.0   65.0    2
# 7893  Yelahanka New Town      1 BHK       500.0   2.0   24.0    1
# 7894  Yelahanka New Town      1 BHK       650.0   1.0   17.0    1
# 7895  Yelahanka New Town      1 BHK       450.0   1.0   16.0    1
# 7896  Yelahanka New Town      3 BHK      1599.0   3.0   80.0    3
# 7897  Yelahanka New Town      2 BHK       960.0   2.0   50.0    2
# 7898  Yelahanka New Town      4 BHK      2095.0   3.0  109.0    4
# 7899  Yelahanka New Town      3 BHK      1209.0   2.0   65.0    3
# 7900  Yelahanka New Town      3 BHK      1400.0   2.0   80.0    3
# 7901  Yelahanka New Town      1 BHK       450.0   1.0   15.0    1
# 7902  Yelahanka New Town      1 BHK       500.0   1.0   18.0    1
# 7903  Yelahanka New Town      3 BHK      1420.0   2.0   75.0    3
# 7904  Yelahanka New Town      3 BHK      2437.0   3.0  125.0    3
# 7905  Yelahanka New Town  2 Bedroom      2200.0   2.0  180.0    2
# 7906  Yelahanka New Town      1 BHK       488.0   1.0   20.0    1
# 7907  Yelahanka New Town      2 BHK      1100.0   2.0   58.0    2
# 7908  Yelahanka New Town      2 BHK       860.0   1.0   31.0    2
# 7909  Yelahanka New Town      3 BHK      1800.0   2.0   45.0    3
# 7910  Yelahanka New Town      2 BHK      1000.0   2.0   44.0    2
# 7911  Yelahanka New Town      1 BHK       650.0   1.0   18.0    1
# 7912  Yelahanka New Town      3 BHK      1426.0   2.0   61.5    3
# 7913  Yelahanka New Town  3 Bedroom      1740.0   3.0  150.0    3
# 7914  Yelahanka New Town      2 BHK      1290.0   2.0   70.0    2
# 7915  Yelahanka New Town      3 BHK      1000.0   2.0   48.0    3
#
#       price_per_sqft
# 7884     5076.923077
# 7885     4000.000000
# 7886     3750.000000
# 7887     5714.285714
# 7888     5294.117647
# 7889     3076.923077
# 7890     3857.142857
# 7891     5191.434134
# 7892     4693.140794
# 7893     4800.000000
# 7894     2615.384615
# 7895     3555.555556
# 7896     5003.126954
# 7897     5208.333333
# 7898     5202.863962
# 7899     5376.344086
# 7900     5714.285714
# 7901     3333.333333
# 7902     3600.000000
# 7903     5281.690141
# 7904     5129.257284
# 7905     8181.818182
# 7906     4098.360656
# 7907     5272.727273
# 7908     3604.651163
# 7909     2500.000000
# 7910     4400.000000
# 7911     2769.230769
# 7912     4312.762973
# 7913     8620.689655
# 7914     5426.356589
# 7915     4800.000000
#          location   size  total_sqft  bath  price  bhk  price_per_sqft
# 7916  Yelenahalli  2 BHK      1240.0   2.0  47.12    2     3800.000000
# 7917  Yelenahalli  2 BHK      1200.0   2.0  46.17    2     3847.500000
# 7918  Yelenahalli  3 BHK      1600.0   3.0  61.37    3     3835.625000
# 7919  Yelenahalli  2 BHK      1260.0   2.0  47.88    2     3800.000000
# 7920  Yelenahalli  3 BHK      1500.0   2.0  57.00    3     3800.000000
# 7921  Yelenahalli  2 BHK      1175.0   2.0  50.00    2     4255.319149
# 7922  Yelenahalli  3 BHK      1650.0   3.0  68.00    3     4121.212121
# 7923  Yelenahalli  2 BHK      1200.0   2.0  45.60    2     3800.000000
# 7924  Yelenahalli  2 BHK      1200.0   2.0  46.17    2     3847.500000
# 7925  Yelenahalli  2 BHK      1160.0   2.0  44.08    2     3800.000000
#           location   size  total_sqft  bath   price  bhk  price_per_sqft
# 7926  Yeshwanthpur  3 BHK      2502.0   3.0  138.00    3     5515.587530
# 7927  Yeshwanthpur  3 BHK      1693.0   3.0  108.00    3     6379.208506
# 7928  Yeshwanthpur  1 BHK       667.0   1.0   36.85    1     5524.737631
# 7929  Yeshwanthpur  4 BHK      1950.0   4.0  130.00    4     6666.666667
# 7930  Yeshwanthpur  2 BHK      1170.0   2.0   57.00    2     4871.794872
# ...            ...    ...         ...   ...     ...  ...             ...
# 7991  Yeshwanthpur  3 BHK      1676.0   3.0   92.13    3     5497.016706
# 7992  Yeshwanthpur  3 BHK      2503.0   3.0  138.00    3     5513.383939
# 7993  Yeshwanthpur  3 BHK      1855.0   3.0  135.00    3     7277.628032
# 7994  Yeshwanthpur  3 BHK      1876.0   3.0  160.00    3     8528.784648
# 7995  Yeshwanthpur  3 BHK      1675.0   3.0   92.13    3     5500.298507
#
# [70 rows x 7 columns]
#       location       size  total_sqft  bath   price  bhk  price_per_sqft
# 7996    others      3 BHK      2770.0   4.0  290.00    3    10469.314079
# 7997    others      2 BHK      1100.0   2.0   48.00    2     4363.636364
# 7998    others      3 BHK      1250.0   3.0   56.00    3     4480.000000
# 7999    others      1 BHK       600.0   1.0   38.00    1     6333.333333
# 8000    others      2 BHK       869.0   2.0   36.00    2     4142.692750
# ...        ...        ...         ...   ...     ...  ...             ...
# 10296   others      2 BHK      1353.0   2.0  110.00    2     8130.081301
# 10297   others  1 Bedroom       812.0   1.0   26.00    1     3201.970443
# 10298   others      3 BHK      1440.0   2.0   63.93    3     4439.583333
# 10299   others      2 BHK      1075.0   2.0   48.00    2     4465.116279
# 10300   others      4 BHK      3600.0   5.0  400.00    4    11111.111111
#
# [2305 rows x 7 columns]

# %%
for bhk, bhk_df in location_df.groupby("bhk"):
    print(bhk_df)
# Out:
#       location       size  total_sqft  bath  price  bhk  price_per_sqft
# 7999    others      1 BHK       600.0   1.0   38.0    1     6333.333333
# 8096    others  1 Bedroom       700.0   1.0   41.0    1     5857.142857
# 8100    others      1 BHK      1200.0   2.0   85.0    1     7083.333333
# 8111    others  1 Bedroom       540.0   1.0   36.0    1     6666.666667
# 8115    others      1 BHK       416.0   1.0   18.5    1     4447.115385
# ...        ...        ...         ...   ...    ...  ...             ...
# 10236   others      1 BHK       450.0   1.0   20.0    1     4444.444444
# 10241   others      1 BHK       540.0   1.0   22.5    1     4166.666667
# 10279   others      1 BHK       530.0   1.0   18.0    1     3396.226415
# 10293   others      1 BHK      1800.0   1.0  200.0    1    11111.111111
# 10297   others  1 Bedroom       812.0   1.0   26.0    1     3201.970443
#
# [132 rows x 7 columns]
#       location   size  total_sqft  bath  price  bhk  price_per_sqft
# 7997    others  2 BHK      1100.0   2.0   48.0    2     4363.636364
# 8000    others  2 BHK       869.0   2.0   36.0    2     4142.692750
# 8001    others  2 BHK      1270.0   2.0   50.0    2     3937.007874
# 8002    others  2 BHK      1500.0   2.0  185.0    2    12333.333333
# 8003    others  2 BHK       840.0   2.0   45.0    2     5357.142857
# ...        ...    ...         ...   ...    ...  ...             ...
# 10292   others  2 BHK      1200.0   2.0   70.0    2     5833.333333
# 10294   others  2 BHK      1095.0   2.0   57.0    2     5205.479452
# 10295   others  2 BHK      1256.0   2.0   65.0    2     5175.159236
# 10296   others  2 BHK      1353.0   2.0  110.0    2     8130.081301
# 10299   others  2 BHK      1075.0   2.0   48.0    2     4465.116279
#
# [987 rows x 7 columns]
#       location       size  total_sqft  bath   price  bhk  price_per_sqft
# 7996    others      3 BHK      2770.0   4.0  290.00    3    10469.314079
# 7998    others      3 BHK      1250.0   3.0   56.00    3     4480.000000
# 8004    others  3 Bedroom      4395.0   3.0  240.00    3     5460.750853
# 8006    others      3 BHK      2511.0   3.0  205.00    3     8164.078057
# 8007    others      3 BHK      1660.0   2.0  105.00    3     6325.301205
# ...        ...        ...         ...   ...     ...  ...             ...
# 10284   others      3 BHK      1490.0   3.0  140.00    3     9395.973154
# 10287   others      3 BHK      1480.0   2.0   75.00    3     5067.567568
# 10288   others      3 BHK      1500.0   2.0   78.00    3     5200.000000
# 10291   others      3 BHK      1508.0   3.0   77.00    3     5106.100796
# 10298   others      3 BHK      1440.0   2.0   63.93    3     4439.583333
#
# [858 rows x 7 columns]
#       location       size  total_sqft  bath  price  bhk  price_per_sqft
# 8035    others      4 BHK      2000.0   4.0   75.5    4     3775.000000
# 8054    others  4 Bedroom      4111.0   4.0  250.0    4     6081.245439
# 8057    others      4 BHK      2000.0   4.0  120.0    4     6000.000000
# 8061    others  4 Bedroom      1200.0   4.0  165.0    4    13750.000000
# 8081    others  4 Bedroom      3309.0   4.0  325.0    4     9821.698398
# ...        ...        ...         ...   ...    ...  ...             ...
# 10262   others      4 BHK      6652.0   6.0  660.0    4     9921.828022
# 10266   others  4 Bedroom      2700.0   3.0  230.0    4     8518.518519
# 10269   others  4 Bedroom      6688.0   6.0  700.0    4    10466.507177
# 10271   others      4 BHK      2872.0   4.0  183.0    4     6371.866295
# 10300   others      4 BHK      3600.0   5.0  400.0    4    11111.111111
#
# [224 rows x 7 columns]
#       location       size  total_sqft  bath  price  bhk  price_per_sqft
# 8186    others  5 Bedroom      4200.0   5.0  225.0    5     5357.142857
# 8188    others  5 Bedroom      1600.0   4.0  125.0    5     7812.500000
# 8213    others  5 Bedroom      1560.0   5.0  145.0    5     9294.871795
# 8214    others  5 Bedroom      2900.0   5.0   90.0    5     3103.448276
# 8296    others  5 Bedroom      1800.0   6.0   44.5    5     2472.222222
# 8299    others  5 Bedroom      2400.0   4.0  300.0    5    12500.000000
# 8389    others      5 BHK      2800.0   4.0  200.0    5     7142.857143
# 8417    others  5 Bedroom      1575.0   4.0  150.0    5     9523.809524
# 8423    others  5 Bedroom      6040.0   4.0  170.0    5     2814.569536
# 8506    others  5 Bedroom      1600.0   5.0  140.0    5     8750.000000
# 8532    others      5 BHK      2000.0   4.0  103.0    5     5150.000000
# 8534    others  5 Bedroom      2400.0   5.0  235.0    5     9791.666667
# 8597    others      5 BHK      6200.0   5.0  720.0    5    11612.903226
# 8670    others  5 Bedroom      2400.0   5.0  120.0    5     5000.000000
# 8737    others      5 BHK      5800.0   5.0   80.0    5     1379.310345
# 8799    others  5 Bedroom      2000.0   4.0  180.0    5     9000.000000
# 8820    others  5 Bedroom      2500.0   5.0  120.0    5     4800.000000
# 8903    others  5 Bedroom      4400.0   4.0  350.0    5     7954.545455
# 8958    others      5 BHK      2000.0   4.0   99.0    5     4950.000000
# 9035    others      5 BHK      2400.0   5.0   93.0    5     3875.000000
# 9037    others  5 Bedroom      2400.0   5.0  285.0    5    11875.000000
# 9047    others      5 BHK      4000.0   3.0  130.0    5     3250.000000
# 9197    others  5 Bedroom      3600.0   5.0  110.0    5     3055.555556
# 9225    others  5 Bedroom      1800.0   4.0   68.0    5     3777.777778
# 9607    others      5 BHK      2700.0   4.0  170.0    5     6296.296296
# 9609    others      5 BHK      3000.0   4.0  300.0    5    10000.000000
# 9675    others  5 Bedroom      8000.0   5.0  550.0    5     6875.000000
# 9721    others  5 Bedroom      3100.0   6.0  165.0    5     5322.580645
# 9756    others  5 Bedroom      4400.0   5.0  240.0    5     5454.545455
# 9829    others  5 Bedroom      2400.0   5.0  150.0    5     6250.000000
# 9835    others  5 Bedroom      2760.0   5.0  140.0    5     5072.463768
# 9846    others  5 Bedroom      3000.0   4.0  170.0    5     5666.666667
# 9878    others  5 Bedroom      2350.0   5.0  325.0    5    13829.787234
# 9918    others  5 Bedroom      2000.0   5.0  240.0    5    12000.000000
# 9981    others  5 Bedroom      3520.0   6.0  460.0    5    13068.181818
# 10022   others  5 Bedroom      2400.0   4.0  325.0    5    13541.666667
# 10104   others  5 Bedroom      2100.0   3.0  145.0    5     6904.761905
# 10125   others  5 Bedroom      1600.0   5.0  140.0    5     8750.000000
# 10141   others  5 Bedroom      1650.0   6.0  200.0    5    12121.212121
# 10182   others  5 Bedroom      2000.0   5.0   75.0    5     3750.000000
# 10216   others  5 Bedroom      2700.0   5.0  150.0    5     5555.555556
# 10217   others  5 Bedroom      3210.0   2.0  353.0    5    10996.884735
#       location       size  total_sqft  bath   price  bhk  price_per_sqft
# 8121    others  6 Bedroom      2160.0   5.0   250.0    6    11574.074074
# 8124    others      6 BHK      3600.0   4.0   160.0    6     4444.444444
# 8297    others      6 BHK      2700.0   4.0   214.0    6     7925.925926
# 8367    others  6 Bedroom      2400.0   4.0   280.0    6    11666.666667
# 8400    others  6 Bedroom      2400.0   7.0   110.0    6     4583.333333
# 8468    others      6 BHK     11338.0   9.0  1000.0    6     8819.897689
# 8556    others  6 Bedroom      2400.0   6.0   245.0    6    10208.333333
# 8607    others  6 Bedroom      2400.0   6.0   130.0    6     5416.666667
# 8612    others  6 Bedroom      2100.0   6.0   275.0    6    13095.238095
# 8668    others  6 Bedroom      2150.0   6.0   205.0    6     9534.883721
# 8779    others  6 Bedroom      2100.0   6.0    71.0    6     3380.952381
# 8881    others      6 BHK      3000.0   8.0    90.0    6     3000.000000
# 9009    others  6 Bedroom      1800.0   3.0   105.0    6     5833.333333
# 9020    others  6 Bedroom      2800.0   4.0   100.0    6     3571.428571
# 9209    others      6 BHK      4250.0   6.0   150.0    6     3529.411765
# 9295    others  6 Bedroom      2300.0   7.0   160.0    6     6956.521739
# 9309    others  6 Bedroom      2400.0   5.0   300.0    6    12500.000000
# 9316    others      6 BHK      2400.0   6.0    98.0    6     4083.333333
# 9414    others  6 Bedroom      1850.0   3.0   175.0    6     9459.459459
# 9440    others  6 Bedroom      2400.0   4.0   170.0    6     7083.333333
# 9622    others  6 Bedroom      3000.0   6.0   300.0    6    10000.000000
# 9767    others  6 Bedroom      4000.0   6.0   460.0    6    11500.000000
# 9841    others      6 BHK      2400.0   5.0    75.0    6     3125.000000
# 9900    others  6 Bedroom      2700.0   7.0   110.0    6     4074.074074
# 9928    others  6 Bedroom      2400.0   7.0   107.0    6     4458.333333
# 9937    others  6 Bedroom      3600.0   6.0   170.0    6     4722.222222
# 9948    others      6 BHK      5100.0   7.0   225.0    6     4411.764706
# 9986    others      6 BHK      3800.0   6.0   390.0    6    10263.157895
# 10000   others  6 Bedroom      7000.0   6.0   560.0    6     8000.000000
# 10043   others  6 Bedroom      2750.0   6.0   200.0    6     7272.727273
# 10171   others  6 Bedroom      3500.0   6.0   115.0    6     3285.714286
# 10231   others      6 BHK      1800.0   6.0   101.0    6     5611.111111
# 10246   others  6 Bedroom     30400.0   4.0  1824.0    6     6000.000000
# 10281   others  6 Bedroom      1800.0   5.0   140.0    6     7777.777778
#      location       size  total_sqft  bath  price  bhk  price_per_sqft
# 8165   others  7 Bedroom      2500.0   6.0  115.0    7     4600.000000
# 8182   others      7 BHK      4100.0   7.0  140.0    7     3414.634146
# 8235   others  7 Bedroom      5000.0   7.0  299.0    7     5980.000000
# 8305   others  7 Bedroom      2800.0   7.0  125.0    7     4464.285714
# 8366   others  7 Bedroom      4400.0   9.0  120.0    7     2727.272727
# 9053   others  7 Bedroom      2800.0   7.0  250.0    7     8928.571429
# 9366   others  7 Bedroom      3600.0   7.0  160.0    7     4444.444444
# 9376   others  7 Bedroom      3000.0   6.0  145.0    7     4833.333333
# 9499   others  7 Bedroom      6500.0   7.0  104.0    7     1600.000000
# 9818   others      7 BHK      4000.0   8.0  150.0    7     3750.000000
# 9955   others  7 Bedroom      4000.0   7.0   90.0    7     2250.000000
#      location       size  total_sqft  bath  price  bhk  price_per_sqft
# 8043   others  8 Bedroom      2600.0   8.0  180.0    8     6923.076923
# 8179   others  8 Bedroom      2400.0   6.0  125.0    8     5208.333333
# 9021   others  8 Bedroom      3500.0   6.0  120.0    8     3428.571429
# 9135   others  8 Bedroom      2500.0   8.0   95.0    8     3800.000000
# 9183   others  8 Bedroom      3150.0   5.0  145.0    8     4603.174603
# 9310   others      8 BHK      3000.0   4.0  130.0    8     4333.333333
# 9962   others      8 BHK      3300.0   8.0  310.0    8     9393.939394
#       location       size  total_sqft  bath  price  bhk  price_per_sqft
# 8681    others  9 Bedroom      4500.0   9.0  166.0    9     3688.888889
# 8818    others      9 BHK      4500.0   9.0  500.0    9    11111.111111
# 9732    others  9 Bedroom      3200.0   8.0  130.0    9     4062.500000
# 10273   others      9 BHK      4600.0   9.0  150.0    9     3260.869565
#      location        size  total_sqft  bath  price  bhk  price_per_sqft
# 8543   others      10 BHK     12000.0  12.0  525.0   10     4375.000000
# 9667   others  10 Bedroom      3300.0   9.0  450.0   10    13636.363636
#      location    size  total_sqft  bath  price  bhk  price_per_sqft
# 8082   others  11 BHK      5000.0   9.0  360.0   11          7200.0
# 9365   others  11 BHK      6000.0  12.0  150.0   11          2500.0
#      location    size  total_sqft  bath  price  bhk  price_per_sqft
# 9697   others  13 BHK      5425.0  13.0  275.0   13     5069.124424
#      location    size  total_sqft  bath  price  bhk  price_per_sqft
# 8632   others  16 BHK     10000.0  16.0  550.0   16          5500.0

# %%
def bhk_outlier_remover(df):
    exclude_indices = np.array([])
    for location, location_df in df.groupby("location"):
        bhk_stats = {}
        for bhk, bhk_df in location_df.groupby("bhk"):
            bhk_stats[bhk] = {
                "mean": np.mean(bhk_df.price_per_sqft), 
                "std": np.std(bhk_df.price_per_sqft),
                "count": bhk_df.shape[0]
        }
        #print(location, bhk_stats)
        for bhk, bhk_df in location_df.groupby("bhk"):
            stats = bhk_stats.get(bhk-1)
            if stats and stats["count"]>5:
                exclude_indices = np.append(exclude_indices, bhk_df[bhk_df.price_per_sqft<(stats["mean"])].index.values)
    return df.drop(exclude_indices, axis="index")

# %%
data = bhk_outlier_remover(data)

# %%
data.shape
# Out:
# (7361, 7)

# %%
data
# Out:
#                   location       size  total_sqft  bath  price  bhk  \
# 0      1st Block Jayanagar      4 BHK      2850.0   4.0  428.0    4
# 1      1st Block Jayanagar      3 BHK      1630.0   3.0  194.0    3
# 2      1st Block Jayanagar      3 BHK      1875.0   2.0  235.0    3
# 3      1st Block Jayanagar      3 BHK      1200.0   2.0  130.0    3
# 4      1st Block Jayanagar      2 BHK      1235.0   2.0  148.0    2
# ...                    ...        ...         ...   ...    ...  ...
# 10292               others      2 BHK      1200.0   2.0   70.0    2
# 10293               others      1 BHK      1800.0   1.0  200.0    1
# 10296               others      2 BHK      1353.0   2.0  110.0    2
# 10297               others  1 Bedroom       812.0   1.0   26.0    1
# 10300               others      4 BHK      3600.0   5.0  400.0    4
#
#        price_per_sqft
# 0        15017.543860
# 1        11901.840491
# 2        12533.333333
# 3        10833.333333
# 4        11983.805668
# ...               ...
# 10292     5833.333333
# 10293    11111.111111
# 10296     8130.081301
# 10297     3201.970443
# 10300    11111.111111
#
# [7361 rows x 7 columns]

# %%
data.drop(columns=["size", "price_per_sqft"], inplace=True)

# %% [markdown]
# ### Cleaned Data

# %%
data.head()
# Out:
#               location  total_sqft  bath  price  bhk
# 0  1st Block Jayanagar      2850.0   4.0  428.0    4
# 1  1st Block Jayanagar      1630.0   3.0  194.0    3
# 2  1st Block Jayanagar      1875.0   2.0  235.0    3
# 3  1st Block Jayanagar      1200.0   2.0  130.0    3
# 4  1st Block Jayanagar      1235.0   2.0  148.0    2

# %%
data.to_csv("Cleaned_data.csv")

# %%
X = data.drop(columns=["price"])
y = data["price"]

# %%
X.head()
# Out:
#               location  total_sqft  bath  bhk
# 0  1st Block Jayanagar      2850.0   4.0    4
# 1  1st Block Jayanagar      1630.0   3.0    3
# 2  1st Block Jayanagar      1875.0   2.0    3
# 3  1st Block Jayanagar      1200.0   2.0    3
# 4  1st Block Jayanagar      1235.0   2.0    2

# %%
y.head()
# Out:
# 0    428.0
# 1    194.0
# 2    235.0
# 3    130.0
# 4    148.0
# Name: price, dtype: float64

# %% [markdown]
# ### Model Building

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression, Lasso, Ridge
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.compose import make_column_transformer
from sklearn.pipeline import make_pipeline
from sklearn.metrics import r2_score

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %%
print(X_train.shape)
print(X_test.shape)
# Out:
# (5888, 4)
# (1473, 4)

# %% [markdown]
# ## Applying Linear Regression

# %%
# One hot encoder ko bas categorical location column pe use karna hai

column_trans = make_column_transformer((OneHotEncoder(sparse=False), ['location']),
                                      remainder="passthrough")

# %%
scaler = StandardScaler()

# %%
lr = LinearRegression(normalize=True)

# %%
pipe = make_pipeline(column_trans, scaler, lr)

# %%
pipe.fit(X_train, y_train)
# Out:
# D:\ProgramData\Programs\Python310\lib\site-packages\sklearn\linear_model\_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LinearRegression())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
#
#   warnings.warn(
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('onehotencoder',
#                                                   OneHotEncoder(sparse=False),
#                                                   ['location'])])),
#                 ('standardscaler', StandardScaler()),
#                 ('linearregression', LinearRegression(normalize=True))])

# %%
y_pred_lr = pipe.predict(X_test)

# %%
r2_score(y_test, y_pred_lr)
# Out:
# 0.8252414810532029

# %% [markdown]
# ## Applying Lasso

# %%
lasso = Lasso()

# %%
pipe2 = make_pipeline(column_trans, scaler, lasso)

# %%
pipe2.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('onehotencoder',
#                                                   OneHotEncoder(sparse=False),
#                                                   ['location'])])),
#                 ('standardscaler', StandardScaler()), ('lasso', Lasso())])

# %%
y_pred_lasso = pipe2.predict(X_test)

# %%
r2_score(y_test, y_pred_lasso)
# Out:
# 0.814689475169039

# %% [markdown]
# ## Applying Ridge

# %%
ridge = Ridge()

# %%
pipe3 = make_pipeline(column_trans, scaler, ridge)

# %%
pipe3.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('onehotencoder',
#                                                   OneHotEncoder(sparse=False),
#                                                   ['location'])])),
#                 ('standardscaler', StandardScaler()), ('ridge', Ridge())])

# %%
y_pred_ridge = pipe3.predict(X_test)

# %%
r2_score(y_test, y_pred_ridge)
# Out:
# 0.825234850229012

# %%
print("No Regularization: ", r2_score(y_test, y_pred_lr))
print("Lasso: ", r2_score(y_test, y_pred_lasso))
print("Ridge: ", r2_score(y_test, y_pred_ridge))
# Out:
# No Regularization:  0.8252414810532029
# Lasso:  0.814689475169039
# Ridge:  0.825234850229012

# %% [markdown]
# ## Dumping the model

# %%
import pickle

# %%
pickle.dump(pipe3, open("RidgeModel.pkl", "wb"))
pickle.dump(pipe, open("LinRegModel.pkl", "wb"))
